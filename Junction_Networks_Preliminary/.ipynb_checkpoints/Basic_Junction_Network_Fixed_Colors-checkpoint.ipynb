# %% [markdown]
# # Basic_Junction_Network_Fixed_Colors
#
# ### Description:
#
# Learns junction parameters for fixed color junctions.

# %%
import pickle
import torch
import torch.nn.functional as F
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from torchvision import transforms
from field_of_junctions import FieldOfJunctions
import sys
sys.path.append('..')

from torchsummary import summary

# %%
# Load data

data_folder = 'foj_data/grayscale_junctions/'

with open(data_folder + 'junction_data_64_20000_fixed_color_center_range_0.pkl','rb') as f:
    data = pickle.load(f)

# wedges = data['wedges']
wedges_grey = data['wedges_grey']
params = data['params']
boundaries = data['boundaries']

# Sort the angles from smallest to largest
temp,_ = torch.sort(params[:,:3],axis=1)
params[:,:3] = temp

dev = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# From fields of junctions
# Would ideally remove this, but script no longer in use

def params2dists(params, R, tau=1e-1):
    """
    Compute distance functions from field of junctions.

    Inputs
    ------
    params   Tensor of shape [N, 5, H', W'] holding N field of junctions parameters. Each
             5-vector has format (angle1, angle2, angle3, x0, y0).
    tau      Constant used for lifting the level set function to be either entirely positive
             or entirely negative when an angle approaches 0 or 2pi.


    Outputs
    -------
             Tensor of shape [N, 2, R, R, H', W'] with samples of the two distance functions for every patch
    """
    
    y, x = torch.meshgrid([torch.linspace(-1.0, 1.0, R, device=dev),
                               torch.linspace(-1.0, 1.0, R, device=dev)],indexing='ij')
    
    x0     = params[:, 3, :, :].unsqueeze(1).unsqueeze(1)   # shape [N, 1, 1, H', W']
    y0     = params[:, 4, :, :].unsqueeze(1).unsqueeze(1)   # shape [N, 1, 1, H', W']

    # Sort so angle1 <= angle2 <= angle3 (mod 2pi)
    angles = torch.remainder(params[:, :3, :, :], 2 * np.pi)
    angles = torch.sort(angles, dim=1)[0]

    angle1 = angles[:, 0, :, :].unsqueeze(1).unsqueeze(1)   # shape [N, 1, 1, H', W']
    angle2 = angles[:, 1, :, :].unsqueeze(1).unsqueeze(1)   # shape [N, 1, 1, H', W']
    angle3 = angles[:, 2, :, :].unsqueeze(1).unsqueeze(1)   # shape [N, 1, 1, H', W']

    # Define another angle halfway between angle3 and angle1, clockwise from angle3
    # This isn't critical but it seems a bit more stable for computing gradients
    angle4 = 0.5 * (angle1 + angle3) + \
                 torch.where(torch.remainder(0.5 * (angle1 - angle3), 2 * np.pi) >= np.pi,
                             torch.ones_like(angle1) * np.pi, torch.zeros_like(angle1))

    def g(dtheta):
        # Map from [0, 2pi] to [-1, 1]
        return (dtheta / np.pi - 1.0) ** 35

    # Compute the two distance functions
    sgn42 = torch.where(torch.remainder(angle2 - angle4, 2 * np.pi) < np.pi,
                        torch.ones_like(angle2), -torch.ones_like(angle2))
    tau42 = g(torch.remainder(angle2 - angle4, 2*np.pi)) * tau

    dist42 = sgn42 * torch.min( sgn42 * (-torch.sin(angle4) * (x - x0) + torch.cos(angle4) * (y - y0)),
                               -sgn42 * (-torch.sin(angle2) * (x - x0) + torch.cos(angle2) * (y - y0))) + tau42

    sgn13 = torch.where(torch.remainder(angle3 - angle1, 2 * np.pi) < np.pi,
                        torch.ones_like(angle3), -torch.ones_like(angle3))
    tau13 = g(torch.remainder(angle3 - angle1, 2*np.pi)) * tau
    dist13 = sgn13 * torch.min( sgn13 * (-torch.sin(angle1) * (x - x0) + torch.cos(angle1) * (y - y0)),
                               -sgn13 * (-torch.sin(angle3) * (x - x0) + torch.cos(angle3) * (y - y0))) + tau13

    return torch.stack([dist13, dist42], dim=1)

def dists2indicators(dists,eta=0.00001):
    """
    Computes the indicator functions u_1, u_2, u_3 from the distance functions d_{13}, d_{12}

    Inputs
    ------
    dists   Tensor of shape [N, 2, R, R, H', W'] with samples of the two distance functions for every patch

    Outputs
    -------
            Tensor of shape [N, 3, R, R, H', W'] with samples of the three indicator functions for every patch
    """
    # Apply smooth Heaviside function to distance functions
    hdists = 0.5 * (1.0 + (2.0 / np.pi) * torch.atan(dists / eta))

    # Convert Heaviside functions into wedge indicator functions
    return torch.stack([1.0 - hdists[:, 0, :, :, :, :],
                              hdists[:, 0, :, :, :, :] * (1.0 - hdists[:, 1, :, :, :, :]),
                              hdists[:, 0, :, :, :, :] *        hdists[:, 1, :, :, :, :]], dim=1)

# %%
# Create data structure with optional transforms

class JunctionDataset(torch.utils.data.Dataset):
    """ Dataset with support of transforms.
    """

    def __init__(self, images, params, boundaries, transform=None):
        self.images = images
        self.params = params
        self.boundaries = boundaries
        self.transform = transform

    def __getitem__(self, index):
        image = self.images[index]

        if self.transform:
            image = self.transform(image)
            
        param = self.params[index].squeeze()
        boundary = self.boundaries[index]
        
        return image, param, boundary

    def __len__(self):
        return len(self.images)
    
    
# transform = transforms.Compose([
#     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
# ])

# %%
# Start by creating wedges as input to the dataset function
params = params.to(dev)


# Create dataset
junction_data = JunctionDataset(wedges_grey, params, boundaries)#, transform=transform)
data_size = len(junction_data)

print(data_size)

train_proportion = .85
# Split dataset into training and testing
train_dataset, test_dataset = torch.utils.data.random_split(junction_data, [int(data_size*train_proportion), int(data_size*(1-train_proportion))], generator=torch.Generator().manual_seed(42))

# Create loaders for the training and testing data
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=100, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False) #len(test_dataset)
# Out:
# 20000

# %% [markdown]
# # Part 1: Create a network to find junction centers

# %%
class centerNet(nn.Module):

    def __init__(self):
        super().__init__()
                
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.maxpool = nn.MaxPool2d(2)
        self.fc0 = nn.Linear(2048, 2048)   
        self.fc1 = nn.Linear(2048, 1024)   
        self.fc2 = nn.Linear(1024, 512)   
        self.fc3 = nn.Linear(512, 256) 
        self.fc4 = nn.Linear(256, 128) 
        self.out = nn.Linear(128, 2)   
    
    def forward(self, x):
        
        x = self.conv1(x)
        x = F.relu(self.maxpool(x))
        x = self.conv2(x)
        x = F.relu(self.maxpool(x))
        x = self.conv3(x)
        x = F.relu(self.maxpool(x))
        x = self.conv4(x)
        x = F.relu(self.maxpool(x))
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = x.view(-1,2048)
        x = F.relu(self.fc0(x))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = self.out(x)

        return x
    
    
model = centerNet()
model = model.to(dev)
summary(model, input_size=(1, 64, 64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 64, 64]             320
#          MaxPool2d-2           [-1, 32, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          18,496
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5          [-1, 128, 16, 16]          73,856
#          MaxPool2d-6            [-1, 128, 8, 8]               0
#             Conv2d-7            [-1, 128, 8, 8]         147,584
#          MaxPool2d-8            [-1, 128, 4, 4]               0
#             Conv2d-9            [-1, 128, 4, 4]         147,584
#            Conv2d-10            [-1, 128, 4, 4]         147,584
#            Linear-11                 [-1, 2048]       4,196,352
#            Linear-12                 [-1, 1024]       2,098,176
#            Linear-13                  [-1, 512]         524,800
#            Linear-14                  [-1, 256]         131,328
#            Linear-15                  [-1, 128]          32,896
#            Linear-16                    [-1, 2]             258
# ================================================================
# Total params: 7,519,234
# Trainable params: 7,519,234
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 2.33
# Params size (MB): 28.68
# Estimated Total Size (MB): 31.03
# ----------------------------------------------------------------

# %%
# Now let's train the initial network 

model.train();

optimizer = torch.optim.Adam(model.parameters(),lr=.01) 
# scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=500, gamma=0.1)

n_epochs = 100

mse_loss = nn.MSELoss()
mae_loss = nn.L1Loss()

def get_loss(output_line_params, output_gt):
            
        loss = mse_loss(output_line_params,output_gt[:,3:])
        
        return loss

def forward_pass(data, training):
    
    # Load inputs from data
    inputs, output_gt, _ = data
    inputs, output_gt = inputs.to(dev), output_gt.to(dev)
    
    # zero the parameter (weight) gradients
    optimizer.zero_grad()
    
    # forward pass to get outputs
    output_line_params = model(inputs)
    
    loss = get_loss(output_line_params,output_gt.squeeze())
    
    if training:

        # backward pass to calculate the parameter gradients
        loss.backward()

        # update the parameters
        optimizer.step()
        
    return output_line_params, loss#, angles_gt_oh
    
for epoch in range(0,n_epochs):  # loop over the dataset multiple times
    
    if epoch == 0:
        train_loss_over_time = [] # to track the loss as the network trains
        test_loss_over_time = []
        
    if epoch == 50:
        optimizer = torch.optim.Adam(model.parameters(),lr=.001) 
        
    running_loss = 0
    num_batches = 0
    
    model.train();
    for batch_i, data in enumerate(train_loader):
        
        # get the input images and their corresponding labels
        num_batches += 1

        _,loss = forward_pass(data, training = 1)

        # to convert loss into a scalar and add it to running_loss, we use .item()
        running_loss += loss.item()
    
    # Calculate test data loss after each epoch
    with torch.no_grad():
        test_loss = 0
        num_batches_test = 0
        for batch_i, data in enumerate(test_loader):
            num_batches_test += 1    

            _,loss = forward_pass(data, training = 0)

            test_loss += loss
                    
        test_loss_over_time.append(test_loss/num_batches_test)

    # Calculate model loss:
    avg_loss = running_loss/num_batches
    train_loss_over_time.append(avg_loss)

    print('Epoch: {}, Avg. Train Loss: {}, Avg. Test Loss: {}'.format(epoch + 1, train_loss_over_time[-1], test_loss_over_time[-1]))
    
print('Finished Training')

plt.figure()
plt.semilogy(np.arange(0,n_epochs),train_loss_over_time[0:])
plt.semilogy(np.arange(0,n_epochs),test_loss_over_time[0:])
plt.legend(['Training loss', 'Testing loss'])
# Out:
# Epoch: 1, Avg. Train Loss: 0.25817121321654696, Avg. Test Loss: 1.7761551589501323e-06
# Epoch: 2, Avg. Train Loss: 8.686067724952676e-07, Avg. Test Loss: 3.85164923955017e-07
# Epoch: 3, Avg. Train Loss: 4.0916856508989866e-07, Avg. Test Loss: 6.980989724070241e-07
# Epoch: 4, Avg. Train Loss: 3.7278060280995947e-07, Avg. Test Loss: 3.470462388577289e-07
# Epoch: 5, Avg. Train Loss: 3.59611856068528e-07, Avg. Test Loss: 9.87271846497606e-07
# Epoch: 6, Avg. Train Loss: 3.659194783100408e-07, Avg. Test Loss: 2.727488435994019e-06
# Epoch: 7, Avg. Train Loss: 3.8745475071981915e-07, Avg. Test Loss: 1.1901327070518164e-06
# Epoch: 8, Avg. Train Loss: 3.4477723530013757e-07, Avg. Test Loss: 1.4650859725406917e-07
# Epoch: 9, Avg. Train Loss: 3.5455250516951553e-07, Avg. Test Loss: 1.5016186694083444e-07
# Epoch: 10, Avg. Train Loss: 2.9573972650145127e-07, Avg. Test Loss: 8.125202839437407e-07
# Epoch: 11, Avg. Train Loss: 3.3674946748493205e-07, Avg. Test Loss: 7.746048424905894e-08
# Epoch: 12, Avg. Train Loss: 2.0359959601655511e-07, Avg. Test Loss: 6.777140271196913e-08
# Epoch: 13, Avg. Train Loss: 2.7484232636170955e-07, Avg. Test Loss: 4.5800792491945685e-08
# Epoch: 14, Avg. Train Loss: 3.1209409486035943e-07, Avg. Test Loss: 7.804964070601272e-07
# Epoch: 15, Avg. Train Loss: 2.1929998614964194e-07, Avg. Test Loss: 4.249987028970281e-08
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-cf77cd995cfd> in <module>
#      54
#      55     model.train();
# ---> 56     for batch_i, data in enumerate(train_loader):
#      57
#      58         # get the input images and their corresponding labels
#
# ~/.conda/envs/torch_cuda9/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/.conda/envs/torch_cuda9/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     559     def _next_data(self):
#     560         index = self._next_index()  # may raise StopIteration
# --> 561         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562         if self._pin_memory:
#     563             data = _utils.pin_memory.pin_memory(data)
#
# ~/.conda/envs/torch_cuda9/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
# ---> 52         return self.collate_fn(data)
#
# ~/.conda/envs/torch_cuda9/lib/python3.6/site-packages/torch/utils/data/_utils/collate.py in default_collate(batch)
#      82             raise RuntimeError('each element in list of batch should be of equal size')
#      83         transposed = zip(*batch)
# ---> 84         return [default_collate(samples) for samples in transposed]
#      85
#      86     raise TypeError(default_collate_err_msg_format.format(elem_type))
#
# ~/.conda/envs/torch_cuda9/lib/python3.6/site-packages/torch/utils/data/_utils/collate.py in <listcomp>(.0)
#      82             raise RuntimeError('each element in list of batch should be of equal size')
#      83         transposed = zip(*batch)
# ---> 84         return [default_collate(samples) for samples in transposed]
#      85
#      86     raise TypeError(default_collate_err_msg_format.format(elem_type))
#
# ~/.conda/envs/torch_cuda9/lib/python3.6/site-packages/torch/utils/data/_utils/collate.py in default_collate(batch)
#      54             storage = elem.storage()._new_shared(numel)
#      55             out = elem.new(storage)
# ---> 56         return torch.stack(batch, 0, out=out)
#      57     elif elem_type.__module__ == 'numpy' and elem_type.__name__ != 'str_' \
#      58             and elem_type.__name__ != 'string_':
#
# KeyboardInterrupt:

# %%
# What should the outputs look like? 

model.eval();

    
data = next(iter(test_loader))

# get the input images and their corresponding labels
inputs, labels, _ = data

inputs, labels = inputs.to(dev), labels.to(dev)

# forward pass to get outputs
outputs = model(inputs).squeeze().detach().cpu()
gt = labels.cpu().squeeze()
    
for ii in range(10):
    
    plt.figure()
    plt.imshow(inputs[ii].cpu().squeeze(),cmap='gray')

    center_output = outputs[ii]*32+32
    center_gt = gt[ii][3:]*32 + 32

    plt.plot(center_gt[0],center_gt[1],'bo',markersize=10)
    plt.plot(center_output[0],center_output[1],'rx',markersize=10)

# %% [markdown]
# # Part 2: Create a network that given the input image and the junction center, finds the three angles

# %%
# Define a loss that is permutation invariant

def overlap_loss(output, target, R=50):

    pred_wedges = dists2indicators(params2dists(output.unsqueeze(-1).unsqueeze(-1),R)).squeeze()
    
    loss1 = torch.sum(pred_wedges + target - 2*pred_wedges*target,axis=(1,2,3))/torch.numel(pred_wedges)
    loss2 = torch.sum(pred_wedges + target[:,[2,0,1],:,:] - 2*pred_wedges*target[:,[2,0,1],:,:],axis=(1,2,3))/torch.numel(pred_wedges)
    loss3 = torch.sum(pred_wedges + target[:,[1,2,0],:,:] - 2*pred_wedges*target[:,[1,2,0],:,:],axis=(1,2,3))/torch.numel(pred_wedges)

    min_loss,_ = torch.Tensor.min(torch.stack((loss1,loss2,loss3),axis=1),axis=1)
    
    return min_loss

# %%
class angleNet(nn.Module):

    def __init__(self):
        super().__init__()
                
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.maxpool = nn.MaxPool2d(2)

        self.fc0 = nn.Linear(2050, 2050*2)   
        self.fc1 = nn.Linear(2050*2, 4098)   
        self.fc2 = nn.Linear(4098, 2048)   
        self.fc3 = nn.Linear(2048, 1024) 
        self.fc4 = nn.Linear(1024, 512) 
        self.out = nn.Linear(512, 6)   
    
    def forward(self, x1, x2):
        
        x = self.conv1(x1)
        x = F.relu(self.maxpool(x))
        x = self.conv2(x)
        x = F.relu(self.maxpool(x))
        x = self.conv3(x)
        x = F.relu(self.maxpool(x))
        x = self.conv4(x)
        x = F.relu(self.maxpool(x))
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = x.view(-1,2048)

        x = torch.cat((x,x2.squeeze(1)),axis=1)
        x = F.relu(self.fc0(x))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = self.out(x)
        
        x = x.reshape(-1,2,3)
        x = (x/(torch.norm(x,p=2,dim=1)).unsqueeze(1).repeat(1,2,1)).flatten(1)
        
        return x
        
model = angleNet()
model = model.to(dev)
# summary(model, input_size=[(1, 64, 64), (1,2)])

# %%
model = angleNet()
model = model.to(dev)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

n_epochs = 100

mse_loss = nn.L1Loss()

model.train();

for epoch in range(0,n_epochs):  # loop over the dataset multiple times

    if epoch == 0:
        train_loss_over_time = [] # to track the loss as the network trains
#         test_loss_over_time = []
        
    running_loss = 0
    num_batches = 0
    for batch_i, data in enumerate(train_loader):
        # get the input images and their corresponding labels
        num_batches += 1

        inputs, params_temp, _, wedge = data
    
        params = torch.cat((torch.cos(params_temp[:,:3]),torch.sin(params_temp[:,:3])),axis=1)
    
        inputs, wedge, params = inputs.to(dev), wedge.to(dev), params.to(dev)
        
        # zero the parameter (weight) gradients
        optimizer.zero_grad()
        
#       net_in = torch.cat((inputs.flatten(2,3),params_temp[:,3:].unsqueeze(1)),axis=2)
                
        # forward pass to get outputs
        output = model(inputs,params_temp[:,3:])
        
#         pred = torch.cat((output[:,:3],params[:,3:]),axis=1)
        
        # calculate the loss
        loss = mse_loss(output,params)#overlap_loss(pred,wedge,R=50).mean()
              
#         loss = torch.minimum(torch.minimum(mse_loss(output,params),mse_loss(output,params[:,[1,2,0,4,5,3]])),mse_loss(output,params[:,[2,0,1,5,3,4]]))

        # backward pass to calculate the parameter gradients
        loss.backward()

        # update the parameters
        optimizer.step()

        # to convert loss into a scalar and add it to running_loss, we use .item()
        running_loss += loss.item()

#     # Calculate test data loss after each epoch
#     with torch.no_grad():
#         test_loss = 0
#         num_batches_test = 0
#         for batch_i, data in enumerate(test_loader):
#             num_batches_test += 1
            
#             inputs_test, params_test, _, wedges_test = data
#             inputs_test, wedges_test, params_test = inputs_test.to(dev), wedges_test.to(dev), params_test.to(dev)
#             output_test = model(inputs_test)
            
#             pred_test = torch.cat((output_test[:,:3],params_test[:,3:]),axis=1)
            
#             test_loss += overlap_loss(pred_test,wedges_test,R=50).mean()
                    
#         test_loss_over_time.append(test_loss/num_batches_test)

    # Calculate model loss:
    avg_loss = running_loss/num_batches
    train_loss_over_time.append(avg_loss)
    
    print('Epoch: {}, Avg. Train Loss: {}'.format(epoch + 1, train_loss_over_time[-1]))
  
#     print('Epoch: {}, Avg. Train Loss: {}, Avg. Test Loss: {}'.format(epoch + 1, train_loss_over_time[-1]),1)#, test_loss_over_time[-1]))
    

print('Finished Training')
# Out:
# Epoch: 1, Avg. Train Loss: 0.5145288050174713
# Epoch: 2, Avg. Train Loss: 0.3541442739612916
# Epoch: 3, Avg. Train Loss: 0.32751180108855754
# Epoch: 4, Avg. Train Loss: 0.25120724176659304
# Epoch: 5, Avg. Train Loss: 0.19741780722842497
# Epoch: 6, Avg. Train Loss: 0.1783225359285579
# Epoch: 7, Avg. Train Loss: 0.17485170206602882
# Epoch: 8, Avg. Train Loss: 0.16862268167383532
# Epoch: 9, Avg. Train Loss: 0.1604077846688383
# Epoch: 10, Avg. Train Loss: 0.15764039018574882
# Epoch: 11, Avg. Train Loss: 0.14775889581617188
# Epoch: 12, Avg. Train Loss: 0.13323865931700257
# Epoch: 13, Avg. Train Loss: 0.08878211348372347
# Epoch: 14, Avg. Train Loss: 0.05597552718485103
# Epoch: 15, Avg. Train Loss: 0.04415376271833392
# Epoch: 16, Avg. Train Loss: 0.03828620962141191
# Epoch: 17, Avg. Train Loss: 0.03489179382210269
# Epoch: 18, Avg. Train Loss: 0.03146055600441554
# Epoch: 19, Avg. Train Loss: 0.02958495604860432
# Epoch: 20, Avg. Train Loss: 0.029228358354200335
# Epoch: 21, Avg. Train Loss: 0.02706002445124528
# Epoch: 22, Avg. Train Loss: 0.025391564244294867
# Epoch: 75, Avg. Train Loss: 0.012934214649174143
# Epoch: 76, Avg. Train Loss: 0.012538536917418242
# Epoch: 77, Avg. Train Loss: 0.013511705332819153
# Epoch: 78, Avg. Train Loss: 0.013053884044946992
# Epoch: 79, Avg. Train Loss: 0.012826725950135905
# Epoch: 80, Avg. Train Loss: 0.01276190861073487
# Epoch: 81, Avg. Train Loss: 0.013225975325878929
# Epoch: 82, Avg. Train Loss: 0.013053927521276123
# Epoch: 83, Avg. Train Loss: 0.013694949935683433
# Epoch: 84, Avg. Train Loss: 0.011862388746265103
# Epoch: 85, Avg. Train Loss: 0.012644895741387325
# Epoch: 86, Avg. Train Loss: 0.013002320384497152
# Epoch: 87, Avg. Train Loss: 0.013205842673778534
# Epoch: 88, Avg. Train Loss: 0.011823685500113403
# Epoch: 89, Avg. Train Loss: 0.012188727255253232
# Epoch: 90, Avg. Train Loss: 0.012099973024690852
# Epoch: 91, Avg. Train Loss: 0.011259525061091956
# Epoch: 92, Avg. Train Loss: 0.012152193300426006
# Epoch: 93, Avg. Train Loss: 0.011652650530723965
# Epoch: 94, Avg. Train Loss: 0.011157329468166126
# Epoch: 95, Avg. Train Loss: 0.011825947633341832
# Epoch: 96, Avg. Train Loss: 0.011819792522446198
# Epoch: 97, Avg. Train Loss: 0.011612053007325705
# Epoch: 98, Avg. Train Loss: 0.012006886906045325
# Epoch: 99, Avg. Train Loss: 0.012360971925013205
# Epoch: 100, Avg. Train Loss: 0.011728778662269606
# Finished Training

# %%
# What do the outputs look like? 

model.eval();

for batch_i, data in enumerate(test_loader):
    # get the input images and their corresponding labels
    inputs, labels, _, _ = data
    
    inputs, labels = inputs.to(dev), labels.to(dev)
    
#     net_in = torch.cat((inputs.flatten(2,3),labels[:,3:].unsqueeze(1)),axis=2)

    # forward pass to get outputs
    outputs = model(inputs,labels[:,3:]).squeeze().detach().cpu()
    
    gt = labels.cpu().squeeze()
    
for ii in range(10):
    
    plt.figure()
    plt.imshow(inputs[ii].cpu().squeeze(),cmap='gray')

    center_gt = gt[ii][3:]*32 + 32

    plt.plot(center_gt[0],center_gt[1],'bo',markersize=10)
    
    line1_end = (center_gt + 10*np.array([np.cos(gt[ii][0]),np.sin(gt[ii][0])]))
    line1 = np.concatenate((center_gt[:,np.newaxis],line1_end[:,np.newaxis]),axis=1)
    
    line2_end = (center_gt + 10*np.array([np.cos(gt[ii][1]),np.sin(gt[ii][1])]))
    line2 = np.concatenate((center_gt[:,np.newaxis],line2_end[:,np.newaxis]),axis=1)
    
    line3_end = (center_gt + 10*np.array([np.cos(gt[ii][2]),np.sin(gt[ii][2])]))
    line3 = np.concatenate((center_gt[:,np.newaxis],line3_end[:,np.newaxis]),axis=1)
    
    plt.plot(line1[0,:],line1[1,:],'-b')
    plt.plot(line2[0,:],line2[1,:],'-b')
    plt.plot(line3[0,:],line3[1,:],'-b')
    
    
    center_output = labels[ii,3:].detach().cpu()*32+32
    
    plt.plot(center_output[0],center_output[1],'ro',markersize=10)

    line1_end = (center_output + 10*np.array([outputs[ii][0],outputs[ii][3]]))
    line1 = np.concatenate((center_output[:,np.newaxis],line1_end[:,np.newaxis]),axis=1)
    
    line2_end = (center_output + 10*np.array([outputs[ii][1],outputs[ii][4]]))
    line2 = np.concatenate((center_output[:,np.newaxis],line2_end[:,np.newaxis]),axis=1)
    
    line3_end = (center_output + 10*np.array([outputs[ii][2],outputs[ii][5]]))
    line3 = np.concatenate((center_output[:,np.newaxis],line3_end[:,np.newaxis]),axis=1)
    
    plt.plot(line1[0,:],line1[1,:],'-r')
    plt.plot(line2[0,:],line2[1,:],'-r')
    plt.plot(line3[0,:],line3[1,:],'-r')

# %% [markdown]
# # Part 3: Now let's combine it all together into one network that finds both the centers and the angles

# %%
class junctionNet(nn.Module):

    def __init__(self):
        super().__init__()
                
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.maxpool = nn.MaxPool2d(2)

        self.fc0 = nn.Linear(2048, 4096)   
        self.fc1 = nn.Linear(4096, 4096)   
        self.fc2 = nn.Linear(4096, 4096)   
        self.fc3 = nn.Linear(4096, 2048)   
        self.fc4 = nn.Linear(2048, 1024) 
        self.fc5 = nn.Linear(1024, 512) 
        self.out = nn.Linear(512, 8)   
    
    def forward(self, x):
        
        x = self.conv1(x)
        x = F.relu(self.maxpool(x))
        x = self.conv2(x)
        x = F.relu(self.maxpool(x))
        x = self.conv3(x)
        x = F.relu(self.maxpool(x))
        x = self.conv4(x)
        x = F.relu(self.maxpool(x))
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = x.view(-1,2048)

        x = F.relu(self.fc0(x))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = F.relu(self.fc5(x))
        x = self.out(x)
        
        x_temp = x[:,:6].reshape(-1,2,3)
        x_temp = (x_temp/(torch.norm(x_temp,p=2,dim=1)).unsqueeze(1).repeat(1,2,1)).flatten(1)
        
        x = torch.cat((x[:,6:],x_temp),axis=1)
        
        return x
        
model = junctionNet()
model = model.to(dev)
summary(model, input_size=[(1, 64, 64)])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 64, 64]             320
#          MaxPool2d-2           [-1, 32, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          18,496
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5          [-1, 128, 16, 16]          73,856
#          MaxPool2d-6            [-1, 128, 8, 8]               0
#             Conv2d-7            [-1, 128, 8, 8]         147,584
#          MaxPool2d-8            [-1, 128, 4, 4]               0
#             Conv2d-9            [-1, 128, 4, 4]         147,584
#            Conv2d-10            [-1, 128, 4, 4]         147,584
#            Linear-11                 [-1, 4096]       8,392,704
#            Linear-12                 [-1, 4096]      16,781,312
#            Linear-13                 [-1, 4096]      16,781,312
#            Linear-14                 [-1, 2048]       8,390,656
#            Linear-15                 [-1, 1024]       2,098,176
#            Linear-16                  [-1, 512]         524,800
#            Linear-17                    [-1, 8]           4,104
# ================================================================
# Total params: 53,508,488
# Trainable params: 53,508,488
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 2.42
# Params size (MB): 204.12
# Estimated Total Size (MB): 206.55
# ----------------------------------------------------------------

# %%
model = junctionNet()
model = model.to(dev)

optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

n_epochs = 200

l1_loss = nn.L1Loss()
mse_loss = nn.MSELoss()

model.train();

for epoch in range(0,n_epochs):  # loop over the dataset multiple times

    if epoch == 0:
        train_loss_over_time = [] # to track the loss as the network trains
#         test_loss_over_time = []
        
    running_loss = 0
    num_batches = 0
    
    for batch_i, data in enumerate(train_loader):
        # get the input images and their corresponding labels
        num_batches += 1

        inputs, params, _, wedge = data
        
        inputs, wedge, params = inputs.to(dev), wedge.to(dev), params.to(dev)
        
        angle_params = torch.cat((torch.cos(params[:,:3]),torch.sin(params[:,:3])),axis=1)
        
        # zero the parameter (weight) gradients
        optimizer.zero_grad()
           
        # forward pass to get outputs
        output = model(inputs)
        
        # calculate the loss
        loss = mse_loss(output[:,6:],params[:,3:]) + l1_loss(output[:,:6],angle_params) 
              
        # backward pass to calculate the parameter gradients
        loss.backward()

        # update the parameters
        optimizer.step()

        # to convert loss into a scalar and add it to running_loss, we use .item()
        running_loss += loss.item()

    # Calculate test data loss after each epoch
    with torch.no_grad():
        test_loss = 0
        num_batches_test = 0
        for batch_i, data in enumerate(test_loader):
            num_batches_test += 1
            
            inputs_test, params_test, _, wedges_test = data
            inputs_test, wedges_test, params_test = inputs_test.to(dev), wedges_test.to(dev), params_test.to(dev)
            
            angle_params_test = torch.cat((torch.cos(params_test[:,:3]),torch.sin(params_test[:,:3])),axis=1)
            output_test = model(inputs_test)
            
            test_loss += mse_loss(output_test[:,6:],params_test[:,3:]) + l1_loss(output_test[:,:6],angle_params_test) 
                    
        test_loss_over_time.append(test_loss/num_batches_test)

    # Calculate model loss:
    avg_loss = running_loss/num_batches
    train_loss_over_time.append(avg_loss)
    
  
    print('Epoch: {}, Avg. Train Loss: {}, Avg. Test Loss: {}'.format(epoch + 1, train_loss_over_time[-1], test_loss_over_time[-1]))
    

print('Finished Training')
# Out:
# Epoch: 192, Avg. Train Loss: 0.10524678046212477, Avg. Test Loss: 0.1083269938826561
# Epoch: 193, Avg. Train Loss: 0.11192246241604581, Avg. Test Loss: 0.10735413432121277
# Epoch: 194, Avg. Train Loss: 0.10297945834258024, Avg. Test Loss: 0.10593397170305252
# Epoch: 195, Avg. Train Loss: 0.10068028652492692, Avg. Test Loss: 0.10258762538433075
# Epoch: 196, Avg. Train Loss: 0.10823899625855334, Avg. Test Loss: 0.11827482283115387
# Epoch: 197, Avg. Train Loss: 0.10714744193588986, Avg. Test Loss: 0.10390184819698334
# Epoch: 198, Avg. Train Loss: 0.10243145065272556, Avg. Test Loss: 0.11749505251646042
# Epoch: 199, Avg. Train Loss: 0.11159849350943285, Avg. Test Loss: 0.1084318533539772
# Epoch: 200, Avg. Train Loss: 0.1063401692053851, Avg. Test Loss: 0.13781455159187317
# Finished Training

# %%
# What do the outputs look like? 

model.eval();

for batch_i, data in enumerate(test_loader):
    # get the input images and their corresponding labels
    inputs, labels, _, _ = data
    
    inputs, labels = inputs.to(dev), labels.to(dev)
    
    # forward pass to get outputs
    outputs = model(inputs).squeeze().detach().cpu()
    
    gt = labels.cpu().squeeze()
    
for ii in range(10):
    
    plt.figure()
    plt.imshow(inputs[ii].cpu().squeeze(),cmap='gray')

    center_gt = gt[ii][3:]*32 + 32

    plt.plot(center_gt[0],center_gt[1],'bo',markersize=10)
    
    line1_end = (center_gt + 10*np.array([np.cos(gt[ii][0]),np.sin(gt[ii][0])]))
    line1 = np.concatenate((center_gt[:,np.newaxis],line1_end[:,np.newaxis]),axis=1)
    
    line2_end = (center_gt + 10*np.array([np.cos(gt[ii][1]),np.sin(gt[ii][1])]))
    line2 = np.concatenate((center_gt[:,np.newaxis],line2_end[:,np.newaxis]),axis=1)
    
    line3_end = (center_gt + 10*np.array([np.cos(gt[ii][2]),np.sin(gt[ii][2])]))
    line3 = np.concatenate((center_gt[:,np.newaxis],line3_end[:,np.newaxis]),axis=1)
    
    plt.plot(line1[0,:],line1[1,:],'-b')
    plt.plot(line2[0,:],line2[1,:],'-b')
    plt.plot(line3[0,:],line3[1,:],'-b')
    
    
    center_output = outputs[ii,6:].detach().cpu()*32+32
    
    plt.plot(center_output[0],center_output[1],'ro',markersize=10)

    line1_end = (center_output + 10*np.array([outputs[ii][0],outputs[ii][3]]))
    line1 = np.concatenate((center_output[:,np.newaxis],line1_end[:,np.newaxis]),axis=1)
    
    line2_end = (center_output + 10*np.array([outputs[ii][1],outputs[ii][4]]))
    line2 = np.concatenate((center_output[:,np.newaxis],line2_end[:,np.newaxis]),axis=1)
    
    line3_end = (center_output + 10*np.array([outputs[ii][2],outputs[ii][5]]))
    line3 = np.concatenate((center_output[:,np.newaxis],line3_end[:,np.newaxis]),axis=1)
    
    plt.plot(line1[0,:],line1[1,:],'-r')
    plt.plot(line2[0,:],line2[1,:],'-r')
    plt.plot(line3[0,:],line3[1,:],'-r')

# %% [markdown]
# # Play around with it

# %% [markdown]
# ### For example, the following:
#
# 1. Adds a LOT of parameters to the junction network
# 2. First trains the network to find centers
# 3. Then refines the 3 angles

# %%
class junctionNet(nn.Module):

    def __init__(self):
        super().__init__()
                
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.maxpool = nn.MaxPool2d(2)

        self.fc0 = nn.Linear(2048, 4096)   
        self.fc1 = nn.Linear(4096, 4096)   
        self.fc2 = nn.Linear(4096, 4096)   
        self.fc3 = nn.Linear(4096, 4096)   
        self.fc4 = nn.Linear(4096, 2048)   
        self.fc5 = nn.Linear(2048, 2048) 
        self.fc6 = nn.Linear(2048, 1024) 
        self.fc7 = nn.Linear(1024, 1024) 
        self.fc8 = nn.Linear(1024, 512) 
        self.out = nn.Linear(512, 8)   
    
    def forward(self, x):
        
        x = self.conv1(x)
        x = F.relu(self.maxpool(x))
        x = self.conv2(x)
        x = F.relu(self.maxpool(x))
        x = self.conv3(x)
        x = F.relu(self.maxpool(x))
        x = self.conv4(x)
        x = F.relu(self.maxpool(x))
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = F.relu(self.conv7(x))
        x = x.view(-1,2048)

        x = F.relu(self.fc0(x))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = F.relu(self.fc5(x))
        x = F.relu(self.fc6(x))
        x = F.relu(self.fc7(x))
        x = F.relu(self.fc8(x))
        x = self.out(x)
        
        x_temp = x[:,:6].reshape(-1,2,3)
        x_temp = (x_temp/(torch.norm(x_temp,p=2,dim=1)).unsqueeze(1).repeat(1,2,1)).flatten(1)
        
        x = torch.cat((x_temp,x[:,6:]),axis=1)
        
        return x
        
model = junctionNet()
model = model.to(dev)
summary(model, input_size=[(1, 64, 64)])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 64, 64]             320
#          MaxPool2d-2           [-1, 32, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          18,496
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5          [-1, 128, 16, 16]          73,856
#          MaxPool2d-6            [-1, 128, 8, 8]               0
#             Conv2d-7            [-1, 128, 8, 8]         147,584
#          MaxPool2d-8            [-1, 128, 4, 4]               0
#             Conv2d-9            [-1, 128, 4, 4]         147,584
#            Conv2d-10            [-1, 128, 4, 4]         147,584
#            Conv2d-11            [-1, 128, 4, 4]         147,584
#            Linear-12                 [-1, 4096]       8,392,704
#            Linear-13                 [-1, 4096]      16,781,312
#            Linear-14                 [-1, 4096]      16,781,312
#            Linear-15                 [-1, 4096]      16,781,312
#            Linear-16                 [-1, 2048]       8,390,656
#            Linear-17                 [-1, 2048]       4,196,352
#            Linear-18                 [-1, 1024]       2,098,176
#            Linear-19                 [-1, 1024]       1,049,600
#            Linear-20                  [-1, 512]         524,800
#            Linear-21                    [-1, 8]           4,104
# ================================================================
# Total params: 75,683,336
# Trainable params: 75,683,336
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 2.49
# Params size (MB): 288.71
# Estimated Total Size (MB): 291.21
# ----------------------------------------------------------------

# %%
# First train & save a version of the network trained to find the junction centers

model = junctionNet()
model = model.to(dev)

optimizer = torch.optim.Adam(model.parameters(), lr=0.0005)

n_epochs = 200

l1_loss = nn.L1Loss()
mse_loss = nn.MSELoss()

model.train();

for epoch in range(0,30):  # loop over the dataset multiple times

    if epoch == 0:
        train_loss_over_time = [] # to track the loss as the network trains
        test_loss_over_time = []
        
    running_loss = 0
    num_batches = 0
    
    for batch_i, data in enumerate(train_loader):
        # get the input images and their corresponding labels
        num_batches += 1

        inputs, params, _, wedge = data
        
        inputs, wedge, params = inputs.to(dev), wedge.to(dev), params.to(dev)
        
        angle_params = torch.cat((torch.cos(params[:,:3]),torch.sin(params[:,:3])),axis=1)
        
        # zero the parameter (weight) gradients
        optimizer.zero_grad()
           
        # forward pass to get outputs
        output = model(inputs)
        
        # calculate the loss
        loss = mse_loss(output[:,6:],params[:,3:])
            
        # backward pass to calculate the parameter gradients
        loss.backward()

        # update the parameters
        optimizer.step()

        # to convert loss into a scalar and add it to running_loss, we use .item()
        running_loss += loss.item()

    # Calculate test data loss after each epoch
    with torch.no_grad():
        test_loss = 0
        num_batches_test = 0
        for batch_i, data in enumerate(test_loader):
            num_batches_test += 1
            
            inputs_test, params_test, _, wedges_test = data
            inputs_test, wedges_test, params_test = inputs_test.to(dev), wedges_test.to(dev), params_test.to(dev)
            
            angle_params_test = torch.cat((torch.cos(params_test[:,:3]),torch.sin(params_test[:,:3])),axis=1)
            output_test = model(inputs_test)

            test_loss += mse_loss(output_test[:,6:],params_test[:,3:])

                    
        test_loss_over_time.append(test_loss/num_batches_test)

    # Calculate model loss:
    avg_loss = running_loss/num_batches
    train_loss_over_time.append(avg_loss)
    
  
    print('Epoch: {}, Avg. Train Loss: {}, Avg. Test Loss: {}'.format(epoch + 1, train_loss_over_time[-1], test_loss_over_time[-1]))
    

print('Finished Training')
# Out:
# Epoch: 1, Avg. Train Loss: 0.0636932529947337, Avg. Test Loss: 0.03662484511733055
# Epoch: 2, Avg. Train Loss: 0.035800730590434635, Avg. Test Loss: 0.030526529997587204
# Epoch: 3, Avg. Train Loss: 0.007993090487605728, Avg. Test Loss: 0.0022321571595966816
# Epoch: 4, Avg. Train Loss: 0.0016220533419126536, Avg. Test Loss: 0.0011500510154291987
# Epoch: 5, Avg. Train Loss: 0.0008161488372613402, Avg. Test Loss: 0.0008302982314489782
# Epoch: 6, Avg. Train Loss: 0.0005683249420732917, Avg. Test Loss: 0.000905777735169977
# Epoch: 7, Avg. Train Loss: 0.0004600150418221293, Avg. Test Loss: 0.0004471448773983866
# Epoch: 8, Avg. Train Loss: 0.0002951916243867291, Avg. Test Loss: 0.0003407723270356655
# Epoch: 9, Avg. Train Loss: 0.00032402671478099794, Avg. Test Loss: 0.0004201448173262179
# Epoch: 10, Avg. Train Loss: 0.00027394480472567545, Avg. Test Loss: 0.0002833547769114375
# Epoch: 11, Avg. Train Loss: 0.0001868979746445, Avg. Test Loss: 0.0003130605327896774
# Epoch: 12, Avg. Train Loss: 0.00019499675832134123, Avg. Test Loss: 0.0003192761796526611
# Epoch: 13, Avg. Train Loss: 0.00020769630911458722, Avg. Test Loss: 0.0003497394791338593
# Epoch: 14, Avg. Train Loss: 0.000160950259605135, Avg. Test Loss: 0.00023539412359241396
# Epoch: 15, Avg. Train Loss: 0.0001813541234107962, Avg. Test Loss: 0.0003066432836931199
# Epoch: 16, Avg. Train Loss: 0.00018151689257459057, Avg. Test Loss: 0.00026235784753225744
# Epoch: 17, Avg. Train Loss: 0.0001430622476618737, Avg. Test Loss: 0.00022820044250693172
# Epoch: 18, Avg. Train Loss: 0.00013490757367381936, Avg. Test Loss: 0.0001955212210305035
# Epoch: 19, Avg. Train Loss: 0.00016986207201090807, Avg. Test Loss: 0.0002175451081711799
# Epoch: 20, Avg. Train Loss: 0.00016994433308889926, Avg. Test Loss: 0.00024011253844946623
# Epoch: 21, Avg. Train Loss: 0.00015490989599664532, Avg. Test Loss: 0.00017775341984815896
# Epoch: 22, Avg. Train Loss: 0.00013093013679762783, Avg. Test Loss: 0.00022519870253745466
# Epoch: 23, Avg. Train Loss: 0.00012828308428973234, Avg. Test Loss: 0.00033289255225099623
# Epoch: 24, Avg. Train Loss: 0.00014897727018893314, Avg. Test Loss: 0.00041086261626333
# Epoch: 25, Avg. Train Loss: 0.00014349637244509615, Avg. Test Loss: 0.00027314259205013514
# Epoch: 26, Avg. Train Loss: 0.00028827594792614144, Avg. Test Loss: 0.0001798392040655017
# Epoch: 27, Avg. Train Loss: 0.00022195821588598738, Avg. Test Loss: 0.00037530992995016277
# Epoch: 28, Avg. Train Loss: 0.00021903391804217417, Avg. Test Loss: 0.00025480997283011675
# Epoch: 29, Avg. Train Loss: 0.0001197592327491079, Avg. Test Loss: 0.00018205931701231748
# Epoch: 30, Avg. Train Loss: 0.00010299714462341988, Avg. Test Loss: 0.00013427430531010032
# Finished Training

# %%
model_loc = './model_weights/centermodel'

torch.save(model.state_dict(), model_loc)

# %%
model = junctionNet()
# Load the trained model:
model.load_state_dict(torch.load(model_loc))

model = model.to(dev)

optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)

n_epochs = 200

l1_loss = nn.L1Loss()
mse_loss = nn.MSELoss()

model.train();

for epoch in range(0,n_epochs):  # loop over the dataset multiple times

    if epoch == 0:
        train_loss_over_time = [] # to track the loss as the network trains
        test_loss_over_time = []
        
#     if epoch > 70:
#         optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)
        
    running_loss = 0
    num_batches = 0
    
    for batch_i, data in enumerate(train_loader):
        # get the input images and their corresponding labels
        num_batches += 1

        inputs, params, _, wedge = data
        
        inputs, wedge, params = inputs.to(dev), wedge.to(dev), params.to(dev)
        
        angle_params = torch.cat((torch.cos(params[:,:3]),torch.sin(params[:,:3])),axis=1)
        
        # zero the parameter (weight) gradients
        optimizer.zero_grad()
           
        # forward pass to get outputs
        output = model(inputs)
        
        # calculate the loss
        loss = mse_loss(output[:,6:],params[:,3:]) + .5*l1_loss(output[:,:6],angle_params) 
              
        # backward pass to calculate the parameter gradients
        loss.backward()

        # update the parameters
        optimizer.step()

        # to convert loss into a scalar and add it to running_loss, we use .item()
        running_loss += loss.item()

    # Calculate test data loss after each epoch
    with torch.no_grad():
        test_loss = 0
        num_batches_test = 0
        for batch_i, data in enumerate(test_loader):
            num_batches_test += 1
            
            inputs_test, params_test, _, wedges_test = data
            inputs_test, wedges_test, params_test = inputs_test.to(dev), wedges_test.to(dev), params_test.to(dev)
            
            angle_params_test = torch.cat((torch.cos(params_test[:,:3]),torch.sin(params_test[:,:3])),axis=1)
            output_test = model(inputs_test)
            
            test_loss += mse_loss(output_test[:,6:],params_test[:,3:]) + .5*l1_loss(output_test[:,:6],angle_params_test) 


                    
        test_loss_over_time.append(test_loss/num_batches_test)

    # Calculate model loss:
    avg_loss = running_loss/num_batches
    train_loss_over_time.append(avg_loss)
    
  
    print('Epoch: {}, Avg. Train Loss: {}, Avg. Test Loss: {}'.format(epoch + 1, train_loss_over_time[-1], test_loss_over_time[-1]))
    

print('Finished Training')
# Out:
# Epoch: 1, Avg. Train Loss: 0.2931851395789315, Avg. Test Loss: 0.24609419703483582
# Epoch: 2, Avg. Train Loss: 0.21894364199217628, Avg. Test Loss: 0.20176471769809723
# Epoch: 3, Avg. Train Loss: 0.18653852922074934, Avg. Test Loss: 0.1763962060213089
# Epoch: 4, Avg. Train Loss: 0.1714930484400076, Avg. Test Loss: 0.1647670716047287
# Epoch: 5, Avg. Train Loss: 0.1595162602031932, Avg. Test Loss: 0.15350674092769623
# Epoch: 6, Avg. Train Loss: 0.149553120925146, Avg. Test Loss: 0.14543774724006653
# Epoch: 7, Avg. Train Loss: 0.1398668623145889, Avg. Test Loss: 0.1340181529521942
# Epoch: 8, Avg. Train Loss: 0.13182825564461595, Avg. Test Loss: 0.12905292212963104
# Epoch: 9, Avg. Train Loss: 0.12501374724156716, Avg. Test Loss: 0.12074051797389984
# Epoch: 10, Avg. Train Loss: 0.11874815558685976, Avg. Test Loss: 0.11313870549201965
# Epoch: 11, Avg. Train Loss: 0.11079299669055377, Avg. Test Loss: 0.10715340822935104
# Epoch: 12, Avg. Train Loss: 0.10521276527467896, Avg. Test Loss: 0.10261815041303635
# Epoch: 13, Avg. Train Loss: 0.10082843391334309, Avg. Test Loss: 0.09946480393409729
# Epoch: 14, Avg. Train Loss: 0.09648522370878387, Avg. Test Loss: 0.09443552792072296
# Epoch: 15, Avg. Train Loss: 0.09410257519168012, Avg. Test Loss: 0.09341996163129807
# Epoch: 16, Avg. Train Loss: 0.09105980979169116, Avg. Test Loss: 0.08975664526224136
# Epoch: 17, Avg. Train Loss: 0.08936926696230384, Avg. Test Loss: 0.08888090401887894
# Epoch: 18, Avg. Train Loss: 0.08648228908286375, Avg. Test Loss: 0.08730965107679367
# Epoch: 19, Avg. Train Loss: 0.08429786028230891, Avg. Test Loss: 0.08469460159540176
# Epoch: 20, Avg. Train Loss: 0.08167187172700377, Avg. Test Loss: 0.08330933749675751
# Epoch: 21, Avg. Train Loss: 0.07917764493647744, Avg. Test Loss: 0.07879997044801712
# Epoch: 22, Avg. Train Loss: 0.07568851864951498, Avg. Test Loss: 0.0763750821352005
# Epoch: 23, Avg. Train Loss: 0.07183345071971417, Avg. Test Loss: 0.07116247713565826
# Epoch: 24, Avg. Train Loss: 0.06762690143111874, Avg. Test Loss: 0.06934966146945953
# Epoch: 25, Avg. Train Loss: 0.06368521261302863, Avg. Test Loss: 0.06412721425294876
# Epoch: 26, Avg. Train Loss: 0.06012943601783584, Avg. Test Loss: 0.0602341890335083
# Epoch: 27, Avg. Train Loss: 0.05537151744698777, Avg. Test Loss: 0.05414074659347534
# Epoch: 121, Avg. Train Loss: 0.006545037461225601, Avg. Test Loss: 0.009144407697021961
# Epoch: 122, Avg. Train Loss: 0.0068571090725634025, Avg. Test Loss: 0.01040744036436081
# Epoch: 123, Avg. Train Loss: 0.0063786623314680425, Avg. Test Loss: 0.009583450853824615
# Epoch: 124, Avg. Train Loss: 0.006188121336676618, Avg. Test Loss: 0.009232159703969955
# Epoch: 125, Avg. Train Loss: 0.006617368292063474, Avg. Test Loss: 0.010500115342438221
# Epoch: 126, Avg. Train Loss: 0.0062701631337404255, Avg. Test Loss: 0.009264977648854256
# Epoch: 127, Avg. Train Loss: 0.006054943276788382, Avg. Test Loss: 0.009471646510064602
# Epoch: 128, Avg. Train Loss: 0.006098031940157799, Avg. Test Loss: 0.009108985774219036
# Epoch: 129, Avg. Train Loss: 0.0062117698958472295, Avg. Test Loss: 0.010266197845339775
# Epoch: 130, Avg. Train Loss: 0.0061970269663588085, Avg. Test Loss: 0.009082397446036339
# Epoch: 131, Avg. Train Loss: 0.006158430734649301, Avg. Test Loss: 0.009914991445839405
# Epoch: 132, Avg. Train Loss: 0.0061898418236523865, Avg. Test Loss: 0.008632577024400234
# Epoch: 133, Avg. Train Loss: 0.0064539221663247135, Avg. Test Loss: 0.008856858126819134
# Epoch: 134, Avg. Train Loss: 0.006307328525273239, Avg. Test Loss: 0.00930718518793583
# Epoch: 135, Avg. Train Loss: 0.006067937415312318, Avg. Test Loss: 0.010269971564412117
# Epoch: 136, Avg. Train Loss: 0.0059130038874333395, Avg. Test Loss: 0.009006259962916374
# Epoch: 137, Avg. Train Loss: 0.006121115063262336, Avg. Test Loss: 0.01004503108561039
# Epoch: 138, Avg. Train Loss: 0.005800633381723481, Avg. Test Loss: 0.010707530193030834
# Epoch: 139, Avg. Train Loss: 0.0059808020370409765, Avg. Test Loss: 0.009391618892550468
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-315-d4333157f68e> in <module>
#      46
#      47         # backward pass to calculate the parameter gradients
# ---> 48         loss.backward()
#      49
#      50         # update the parameters
#
# ~/.conda/envs/torch_cuda9/lib/python3.6/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# ~/.conda/envs/torch_cuda9/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     157
#     158
#
# KeyboardInterrupt:

# %%
plt.figure()
plt.plot(train_loss_over_time)


plt.figure()
plt.plot(test_loss_over_time)

# %%
# What do the outputs look like? 

model.eval();

for batch_i, data in enumerate(test_loader):
    # get the input images and their corresponding labels
    inputs, labels, _, _ = data
    
    inputs, labels = inputs.to(dev), labels.to(dev)
    
    # forward pass to get outputs
    outputs = model(inputs).squeeze().detach().cpu()
    
    gt = labels.cpu().squeeze()
    
for ii in range(20):
    
    plt.figure()
    plt.imshow(inputs[ii].cpu().squeeze(),cmap='gray')

    center_gt = gt[ii][3:]*32 + 32

    plt.plot(center_gt[0],center_gt[1],'bo',markersize=10)
    
    line1_end = (center_gt + 10*np.array([np.cos(gt[ii][0]),np.sin(gt[ii][0])]))
    line1 = np.concatenate((center_gt[:,np.newaxis],line1_end[:,np.newaxis]),axis=1)
    
    line2_end = (center_gt + 10*np.array([np.cos(gt[ii][1]),np.sin(gt[ii][1])]))
    line2 = np.concatenate((center_gt[:,np.newaxis],line2_end[:,np.newaxis]),axis=1)
    
    line3_end = (center_gt + 10*np.array([np.cos(gt[ii][2]),np.sin(gt[ii][2])]))
    line3 = np.concatenate((center_gt[:,np.newaxis],line3_end[:,np.newaxis]),axis=1)
    
    plt.plot(line1[0,:],line1[1,:],'-b')
    plt.plot(line2[0,:],line2[1,:],'-b')
    plt.plot(line3[0,:],line3[1,:],'-b')
    
    
    center_output = outputs[ii,6:].detach().cpu()*32+32
    
    plt.plot(center_output[0],center_output[1],'ro',markersize=10)

    line1_end = (center_output + 10*np.array([outputs[ii][0],outputs[ii][3]]))
    line1 = np.concatenate((center_output[:,np.newaxis],line1_end[:,np.newaxis]),axis=1)
    
    line2_end = (center_output + 10*np.array([outputs[ii][1],outputs[ii][4]]))
    line2 = np.concatenate((center_output[:,np.newaxis],line2_end[:,np.newaxis]),axis=1)
    
    line3_end = (center_output + 10*np.array([outputs[ii][2],outputs[ii][5]]))
    line3 = np.concatenate((center_output[:,np.newaxis],line3_end[:,np.newaxis]),axis=1)
    
    plt.plot(line1[0,:],line1[1,:],'-r')
    plt.plot(line2[0,:],line2[1,:],'-r')
    plt.plot(line3[0,:],line3[1,:],'-r')

# %% [markdown]
# ### Alternatively, train the centers and angles in tandem

# %%
# Post Question 1: Can it train without the initial center training step or does that help?

model = junctionNet()
model = model.to(dev)

optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)

n_epochs = 200

l1_loss = nn.L1Loss()
mse_loss = nn.MSELoss()

model.train();

for epoch in range(0,n_epochs):  # loop over the dataset multiple times

    if epoch == 0:
        train_loss_over_time = [] # to track the loss as the network trains
        test_loss_over_time = []
        
#     if epoch > 70:
#         optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)
        
    running_loss = 0
    num_batches = 0
    
    for batch_i, data in enumerate(train_loader):
        # get the input images and their corresponding labels
        num_batches += 1

        inputs, params, _, wedge = data
        
        inputs, wedge, params = inputs.to(dev), wedge.to(dev), params.to(dev)
        
        angle_params = torch.cat((torch.cos(params[:,:3]),torch.sin(params[:,:3])),axis=1)
        
        # zero the parameter (weight) gradients
        optimizer.zero_grad()
           
        # forward pass to get outputs
        output = model(inputs)
        
        # calculate the loss
        loss = mse_loss(output[:,6:],params[:,3:]) + .5*l1_loss(output[:,:6],angle_params) 
              
        # backward pass to calculate the parameter gradients
        loss.backward()

        # update the parameters
        optimizer.step()

        # to convert loss into a scalar and add it to running_loss, we use .item()
        running_loss += loss.item()

    # Calculate test data loss after each epoch
    with torch.no_grad():
        test_loss = 0
        num_batches_test = 0
        for batch_i, data in enumerate(test_loader):
            num_batches_test += 1
            
            inputs_test, params_test, _, wedges_test = data
            inputs_test, wedges_test, params_test = inputs_test.to(dev), wedges_test.to(dev), params_test.to(dev)
            
            angle_params_test = torch.cat((torch.cos(params_test[:,:3]),torch.sin(params_test[:,:3])),axis=1)
            output_test = model(inputs_test)
            
            test_loss += mse_loss(output_test[:,6:],params_test[:,3:]) + .5*l1_loss(output_test[:,:6],angle_params_test) 


                    
        test_loss_over_time.append(test_loss/num_batches_test)

    # Calculate model loss:
    avg_loss = running_loss/num_batches
    train_loss_over_time.append(avg_loss)
    
  
    print('Epoch: {}, Avg. Train Loss: {}, Avg. Test Loss: {}'.format(epoch + 1, train_loss_over_time[-1], test_loss_over_time[-1]))
    

print('Finished Training')
# Out:
# Epoch: 1, Avg. Train Loss: 0.38441418917740094, Avg. Test Loss: 0.3500439524650574
# Epoch: 2, Avg. Train Loss: 0.3396535184453515, Avg. Test Loss: 0.3317245841026306
# Epoch: 3, Avg. Train Loss: 0.3201366252758924, Avg. Test Loss: 0.27200254797935486
# Epoch: 4, Avg. Train Loss: 0.23285519883913153, Avg. Test Loss: 0.21421244740486145
# Epoch: 5, Avg. Train Loss: 0.20241048563929165, Avg. Test Loss: 0.18534497916698456
# Epoch: 6, Avg. Train Loss: 0.1849074537263197, Avg. Test Loss: 0.1810397207736969
# Epoch: 7, Avg. Train Loss: 0.1718489308567608, Avg. Test Loss: 0.16120778024196625
# Epoch: 8, Avg. Train Loss: 0.1593292756115689, Avg. Test Loss: 0.15358556807041168
# Epoch: 9, Avg. Train Loss: 0.1385396628695376, Avg. Test Loss: 0.12370947003364563
# Epoch: 10, Avg. Train Loss: 0.12074025282088448, Avg. Test Loss: 0.12167470902204514
# Epoch: 11, Avg. Train Loss: 0.11672880307716482, Avg. Test Loss: 0.11322285979986191
# Epoch: 12, Avg. Train Loss: 0.11299503634081168, Avg. Test Loss: 0.10871151089668274
# Epoch: 13, Avg. Train Loss: 0.10810757156680612, Avg. Test Loss: 0.10468710213899612
# Epoch: 14, Avg. Train Loss: 0.10529374155928106, Avg. Test Loss: 0.10263188928365707
# Epoch: 15, Avg. Train Loss: 0.10273955302203402, Avg. Test Loss: 0.1006760522723198
# Epoch: 16, Avg. Train Loss: 0.10053919391597019, Avg. Test Loss: 0.09769615530967712
= nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.maxpool = nn.MaxPool2d(2)

        self.fc0 = nn.Linear(2048, 4096)   
        self.fc1 = nn.Linear(4096, 4096)   
        self.fc2 = nn.Linear(4096, 2048)   
        self.fc3 = nn.Linear(2048, 1024) 
        self.fc4 = nn.Linear(1024, 1024) 
        self.fc5 = nn.Linear(1024, 512) 
        self.out = nn.Linear(512, 8)   
    
    def forward(self, x):
        
        x = self.conv1(x)
        x = F.relu(self.maxpool(x))
        x = self.conv2(x)
        x = F.relu(self.maxpool(x))
        x = self.conv3(x)
        x = F.relu(self.maxpool(x))
        x = self.conv4(x)
        x = F.relu(self.maxpool(x))
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = F.relu(self.conv7(x))
        x = x.view(-1,2048)

        x = F.relu(self.fc0(x))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = F.relu(self.fc4(x))
        x = F.relu(self.fc5(x))
#         x = F.relu(self.fc6(x))
#         x = F.relu(self.fc7(x))
#         x = F.relu(self.fc8(x))
        x = self.out(x)
        
        x_temp = x[:,:6].reshape(-1,2,3)
        x_temp = (x_temp/(torch.norm(x_temp,p=2,dim=1)).unsqueeze(1).repeat(1,2,1)).flatten(1)
        
        x = torch.cat((x_temp,x[:,6:]),axis=1)
        
        return x
        
model = junctionNet()
model = model.to(dev)
summary(model, input_size=[(1, 64, 64)])

optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)

n_epochs = 200

l1_loss = nn.L1Loss()
mse_loss = nn.MSELoss()

model.train();

for epoch in range(0,n_epochs):  # loop over the dataset multiple times

    if epoch == 0:
        train_loss_over_time = [] # to track the loss as the network trains
        test_loss_over_time = []
        
#     if epoch > 70:
#         optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)
        
    running_loss = 0
    num_batches = 0
    
    for batch_i, data in enumerate(train_loader):
        # get the input images and their corresponding labels
        num_batches += 1

        inputs, params, _, wedge = data
        
        inputs, wedge, params = inputs.to(dev), wedge.to(dev), params.to(dev)
        
        angle_params = torch.cat((torch.cos(params[:,:3]),torch.sin(params[:,:3])),axis=1)
        
        # zero the parameter (weight) gradients
        optimizer.zero_grad()
           
        # forward pass to get outputs
        output = model(inputs)
        
        # calculate the loss
        loss = mse_loss(output[:,6:],params[:,3:]) + .5*l1_loss(output[:,:6],angle_params) 
              
        # backward pass to calculate the parameter gradients
        loss.backward()

        # update the parameters
        optimizer.step()

        # to convert loss into a scalar and add it to running_loss, we use .item()
        running_loss += loss.item()

    # Calculate test data loss after each epoch
    with torch.no_grad():
        test_loss = 0
        num_batches_test = 0
        for batch_i, data in enumerate(test_loader):
            num_batches_test += 1
            
            inputs_test, params_test, _, wedges_test = data
            inputs_test, wedges_test, params_test = inputs_test.to(dev), wedges_test.to(dev), params_test.to(dev)
            
            angle_params_test = torch.cat((torch.cos(params_test[:,:3]),torch.sin(params_test[:,:3])),axis=1)
            output_test = model(inputs_test)
            
            test_loss += mse_loss(output_test[:,6:],params_test[:,3:]) + .5*l1_loss(output_test[:,:6],angle_params_test) 


                    
        test_loss_over_time.append(test_loss/num_batches_test)

    # Calculate model loss:
    avg_loss = running_loss/num_batches
    train_loss_over_time.append(avg_loss)
    
  
    print('Epoch: {}, Avg. Train Loss: {}, Avg. Test Loss: {}'.format(epoch + 1, train_loss_over_time[-1], test_loss_over_time[-1]))
    

print('Finished Training')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 64, 64]             320
#          MaxPool2d-2           [-1, 32, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          18,496
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5          [-1, 128, 16, 16]          73,856
#          MaxPool2d-6            [-1, 128, 8, 8]               0
#             Conv2d-7            [-1, 128, 8, 8]         147,584
#          MaxPool2d-8            [-1, 128, 4, 4]               0
#             Conv2d-9            [-1, 128, 4, 4]         147,584
#            Conv2d-10            [-1, 128, 4, 4]         147,584
#            Conv2d-11            [-1, 128, 4, 4]         147,584
#            Linear-12                 [-1, 4096]       8,392,704
#            Linear-13                 [-1, 4096]      16,781,312
#            Linear-14                 [-1, 2048]       8,390,656
#            Linear-15                 [-1, 1024]       2,098,176
#            Linear-16                 [-1, 1024]       1,049,600
#            Linear-17                  [-1, 512]         524,800
#            Linear-18                    [-1, 8]           4,104
# ================================================================
# Total params: 37,924,360
# Trainable params: 37,924,360
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 2.41
# Params size (MB): 144.67
# Estimated Total Size (MB): 147.10
# ----------------------------------------------------------------
# Epoch: 1, Avg. Train Loss: 0.392124809587703, Avg. Test Loss: 0.3523845672607422
# Epoch: 2, Avg. Train Loss: 0.31066135299556397, Avg. Test Loss: 0.25059473514556885
# Epoch: 3, Avg. Train Loss: 0.2242205724996679, Avg. Test Loss: 0.20795755088329315
# Epoch: 4, Avg. Train Loss: 0.17778804179500132, Avg. Test Loss: 0.15473154187202454
# Epoch: 5, Avg. Train Loss: 0.14614541030981962, Avg. Test Loss: 0.1284201592206955
# Epoch: 192, Avg. Train Loss: 0.005529097266330877, Avg. Test Loss: 0.006641755811870098
# Epoch: 193, Avg. Train Loss: 0.005706602699287674, Avg. Test Loss: 0.0075605991296470165
# Epoch: 194, Avg. Train Loss: 0.005595365755588693, Avg. Test Loss: 0.006941971369087696
# Epoch: 195, Avg. Train Loss: 0.005840982674785397, Avg. Test Loss: 0.007212426047772169
# Epoch: 196, Avg. Train Loss: 0.005510946954874431, Avg. Test Loss: 0.007270616013556719
# Epoch: 197, Avg. Train Loss: 0.005624035428113797, Avg. Test Loss: 0.007445547729730606
# Epoch: 198, Avg. Train Loss: 0.0057956944630645655, Avg. Test Loss: 0.007332801353186369
# Epoch: 199, Avg. Train Loss: 0.0055615044253713945, Avg. Test Loss: 0.006696614902466536
# Epoch: 200, Avg. Train Loss: 0.005525172655196751, Avg. Test Loss: 0.0072264703921973705
# Finished Training

# %%
# What do the outputs look like? 

model.eval();

for batch_i, data in enumerate(test_loader):
    # get the input images and their corresponding labels
    inputs, labels, _, _ = data
    
    inputs, labels = inputs.to(dev), labels.to(dev)
    
    # forward pass to get outputs
    outputs = model(inputs).squeeze().detach().cpu()
    
    gt = labels.cpu().squeeze()
    
for ii in range(20):
    
    plt.figure()
    plt.imshow(inputs[ii].cpu().squeeze(),cmap='gray')

    center_gt = gt[ii][3:]*32 + 32

    plt.plot(center_gt[0],center_gt[1],'bo',markersize=10)
    
    line1_end = (center_gt + 10*np.array([np.cos(gt[ii][0]),np.sin(gt[ii][0])]))
    line1 = np.concatenate((center_gt[:,np.newaxis],line1_end[:,np.newaxis]),axis=1)
    
    line2_end = (center_gt + 10*np.array([np.cos(gt[ii][1]),np.sin(gt[ii][1])]))
    line2 = np.concatenate((center_gt[:,np.newaxis],line2_end[:,np.newaxis]),axis=1)
    
    line3_end = (center_gt + 10*np.array([np.cos(gt[ii][2]),np.sin(gt[ii][2])]))
    line3 = np.concatenate((center_gt[:,np.newaxis],line3_end[:,np.newaxis]),axis=1)
    
    plt.plot(line1[0,:],line1[1,:],'-b')
    plt.plot(line2[0,:],line2[1,:],'-b')
    plt.plot(line3[0,:],line3[1,:],'-b')
    
    
    center_output = outputs[ii,6:].detach().cpu()*32+32
    
    plt.plot(center_output[0],center_output[1],'ro',markersize=10)

    line1_end = (center_output + 10*np.array([outputs[ii][0],outputs[ii][3]]))
    line1 = np.concatenate((center_output[:,np.newaxis],line1_end[:,np.newaxis]),axis=1)
    
    line2_end = (center_output + 10*np.array([outputs[ii][1],outputs[ii][4]]))
    line2 = np.concatenate((center_output[:,np.newaxis],line2_end[:,np.newaxis]),axis=1)
    
    line3_end = (center_output + 10*np.array([outputs[ii][2],outputs[ii][5]]))
    line3 = np.concatenate((center_output[:,np.newaxis],line3_end[:,np.newaxis]),axis=1)
    
    plt.plot(line1[0,:],line1[1,:],'-r')
    plt.plot(line2[0,:],line2[1,:],'-r')
    plt.plot(line3[0,:],line3[1,:],'-r')

# %%
# About the same, let's reduce it more

class junctionNet(nn.Module):

    def __init__(self):
        super().__init__()
                
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.conv7 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.maxpool = nn.MaxPool2d(2)

        self.fc0 = nn.Linear(2048, 4096)   
        self.fc1 = nn.Linear(4096, 4096)   
        self.fc2 = nn.Linear(4096, 512)   
#         self.fc3 = nn.Linear(2048, 1024) 
#         self.fc4 = nn.Linear(1024, 1024) 
#         self.fc5 = nn.Linear(1024, 512) 
        self.out = nn.Linear(512, 8)   
    
    def forward(self, x):
        
        x = self.conv1(x)
        x = F.relu(self.maxpool(x))
        x = self.conv2(x)
        x = F.relu(self.maxpool(x))
        x = self.conv3(x)
        x = F.relu(self.maxpool(x))
        x = self.conv4(x)
        x = F.relu(self.maxpool(x))
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = F.relu(self.conv7(x))
        x = x.view(-1,2048)

        x = F.relu(self.fc0(x))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
#         x = F.relu(self.fc3(x))
#         x = F.relu(self.fc4(x))
#         x = F.relu(self.fc5(x))
#         x = F.relu(self.fc6(x))
#         x = F.relu(self.fc7(x))
#         x = F.relu(self.fc8(x))
        x = self.out(x)
        
        x_temp = x[:,:6].reshape(-1,2,3)
        x_temp = (x_temp/(torch.norm(x_temp,p=2,dim=1)).unsqueeze(1).repeat(1,2,1)).flatten(1)
        
        x = torch.cat((x_temp,x[:,6:]),axis=1)
        
        return x
        
model = junctionNet()
model = model.to(dev)
summary(model, input_size=[(1, 64, 64)])

optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)

n_epochs = 200

l1_loss = nn.L1Loss()
mse_loss = nn.MSELoss()

model.train();

for epoch in range(0,n_epochs):  # loop over the dataset multiple times

    if epoch == 0:
        train_loss_over_time = [] # to track the loss as the network trains
        test_loss_over_time = []
        
#     if epoch > 70:
#         optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)
        
    running_loss = 0
    num_batches = 0
    
    for batch_i, data in enumerate(train_loader):
        # get the input images and their corresponding labels
        num_batches += 1

        inputs, params, _, wedge = data
        
        inputs, wedge, params = inputs.to(dev), wedge.to(dev), params.to(dev)
        
        angle_params = torch.cat((torch.cos(params[:,:3]),torch.sin(params[:,:3])),axis=1)
        
        # zero the parameter (weight) gradients
        optimizer.zero_grad()
           
        # forward pass to get outputs
        output = model(inputs)
        
        # calculate the loss
        loss = mse_loss(output[:,6:],params[:,3:]) + .1*l1_loss(output[:,:6],angle_params) 
              
        # backward pass to calculate the parameter gradients
        loss.backward()

        # update the parameters
        optimizer.step()

        # to convert loss into a scalar and add it to running_loss, we use .item()
        running_loss += loss.item()

    # Calculate test data loss after each epoch
    with torch.no_grad():
        test_loss = 0
        num_batches_test = 0
        for batch_i, data in enumerate(test_loader):
            num_batches_test += 1
            
            inputs_test, params_test, _, wedges_test = data
            inputs_test, wedges_test, params_test = inputs_test.to(dev), wedges_test.to(dev), params_test.to(dev)
            
            angle_params_test = torch.cat((torch.cos(params_test[:,:3]),torch.sin(params_test[:,:3])),axis=1)
            output_test = model(inputs_test)
            
            test_loss += mse_loss(output_test[:,6:],params_test[:,3:]) + .1*l1_loss(output_test[:,:6],angle_params_test) 


                    
        test_loss_over_time.append(test_loss/num_batches_test)

    # Calculate model loss:
    avg_loss = running_loss/num_batches
    train_loss_over_time.append(avg_loss)
    
  
    print('Epoch: {}, Avg. Train Loss: {}, Avg. Test Loss: {}'.format(epoch + 1, train_loss_over_time[-1], test_loss_over_time[-1]))
    

print('Finished Training')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 64, 64]             320
#          MaxPool2d-2           [-1, 32, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          18,496
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5          [-1, 128, 16, 16]          73,856
#          MaxPool2d-6            [-1, 128, 8, 8]               0
#             Conv2d-7            [-1, 128, 8, 8]         147,584
#          MaxPool2d-8            [-1, 128, 4, 4]               0
#             Conv2d-9            [-1, 128, 4, 4]         147,584
#            Conv2d-10            [-1, 128, 4, 4]         147,584
#            Conv2d-11            [-1, 128, 4, 4]         147,584
#            Linear-12                 [-1, 4096]       8,392,704
#            Linear-13                 [-1, 4096]      16,781,312
#            Linear-14                  [-1, 512]       2,097,664
#            Linear-15                    [-1, 8]           4,104
# ================================================================
# Total params: 27,958,792
# Trainable params: 27,958,792
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 2.38
# Params size (MB): 106.65
# Estimated Total Size (MB): 109.05
# ----------------------------------------------------------------
# Epoch: 1, Avg. Train Loss: 0.14277890591936954, Avg. Test Loss: 0.12299031764268875
# Epoch: 2, Avg. Train Loss: 0.09645616635680199, Avg. Test Loss: 0.06347409635782242
# Epoch: 3, Avg. Train Loss: 0.049314111449262676, Avg. Test Loss: 0.041026774793863297
# Epoch: 4, Avg. Train Loss: 0.03199413221548585, Avg. Test Loss: 0.026813805103302002
# Epoch: 5, Avg. Train Loss: 0.024366936186218963, Avg. Test Loss: 0.0219879113137722
# Epoch: 6, Avg. Train Loss: 0.01875414672472021, Avg. Test Loss: 0.01635029911994934
# Epoch: 7, Avg. Train Loss: 0.014738483606454205, Avg. Test Loss: 0.01292291097342968
# Epoch: 8, Avg. Train Loss: 0.012263415474444627, Avg. Test Loss: 0.013567894697189331
# Epoch: 9, Avg. Train Loss: 0.011121607117135736, Avg. Test Loss: 0.01017138734459877
# Epoch: 10, Avg. Train Loss: 0.009785442078924355, Avg. Test Loss: 0.00945389736443758
# Epoch: 133, Avg. Train Loss: 0.0012539245379979119, Avg. Test Loss: 0.0016853014240041375
# Epoch: 134, Avg. Train Loss: 0.0011081739893758341, Avg. Test Loss: 0.0014720532344654202
# Epoch: 135, Avg. Train Loss: 0.0011677693945410497, Avg. Test Loss: 0.001792620518244803
# Epoch: 136, Avg. Train Loss: 0.0011837445874013665, Avg. Test Loss: 0.0016749616479501128
# Epoch: 137, Avg. Train Loss: 0.0011615710675387698, Avg. Test Loss: 0.0014929674798622727
# Epoch: 138, Avg. Train Loss: 0.0011505725735332817, Avg. Test Loss: 0.0016277870163321495
# Epoch: 139, Avg. Train Loss: 0.0012073463414494386, Avg. Test Loss: 0.0017125123413279653
# Epoch: 140, Avg. Train Loss: 0.0011218492547734914, Avg. Test Loss: 0.001539992168545723
# Epoch: 141, Avg. Train Loss: 0.0011392470158170908, Avg. Test Loss: 0.002006958704441786
# Epoch: 142, Avg. Train Loss: 0.001145302871694131, Avg. Test Loss: 0.0014831307344138622
# Epoch: 143, Avg. Train Loss: 0.001107772338368437, Avg. Test Loss: 0.0015165164368227124
# Epoch: 144, Avg. Train Loss: 0.001138800648999784, Avg. Test Loss: 0.00214595184661448
# Epoch: 145, Avg. Train Loss: 0.0011108474148546947, Avg. Test Loss: 0.0016955977771431208
# Epoch: 146, Avg. Train Loss: 0.0011395576252492474, Avg. Test Loss: 0.0017910310998558998
# Epoch: 147, Avg. Train Loss: 0.0011179551834870568, Avg. Test Loss: 0.0016188174486160278
# Epoch: 148, Avg. Train Loss: 0.0011030464792651507, Avg. Test Loss: 0.0015398977557197213
# Epoch: 149, Avg. Train Loss: 0.0010977230291567086, Avg. Test Loss: 0.0015804341528564692
# Epoch: 150, Avg. Train Loss: 0.0010409342566751602, Avg. Test Loss: 0.0015168067766353488
# Epoch: 151, Avg. Train Loss: 0.001064877103849807, Avg. Test Loss: 0.0014885823475196958
# Epoch: 152, Avg. Train Loss: 0.0010464477900634793, Avg. Test Loss: 0.0017401681980118155
# Epoch: 153, Avg. Train Loss: 0.0010575363046133562, Avg. Test Loss: 0.001488177920691669
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-326-08916653f4d3> in <module>
#     109
#     110         # to convert loss into a scalar and add it to running_loss, we use .item()
# --> 111         running_loss += loss.item()
#     112
#     113     # Calculate test data loss after each epoch
#
# KeyboardInterrupt:

# %%
# What do the outputs look like? 

model.eval();

for batch_i, data in enumerate(test_loader):
    # get the input images and their corresponding labels
    inputs, labels, _, _ = data
    
    inputs, labels = inputs.to(dev), labels.to(dev)
    
    # forward pass to get outputs
    outputs = model(inputs).squeeze().detach().cpu()
    
    gt = labels.cpu().squeeze()
    
for ii in range(20):
    
    plt.figure()
    plt.imshow(inputs[ii].cpu().squeeze(),cmap='gray')

    center_gt = gt[ii][3:]*32 + 32

    plt.plot(center_gt[0],center_gt[1],'bo',markersize=10)
    
    line1_end = (center_gt + 10*np.array([np.cos(gt[ii][0]),np.sin(gt[ii][0])]))
    line1 = np.concatenate((center_gt[:,np.newaxis],line1_end[:,np.newaxis]),axis=1)
    
    line2_end = (center_gt + 10*np.array([np.cos(gt[ii][1]),np.sin(gt[ii][1])]))
    line2 = np.concatenate((center_gt[:,np.newaxis],line2_end[:,np.newaxis]),axis=1)
    
    line3_end = (center_gt + 10*np.array([np.cos(gt[ii][2]),np.sin(gt[ii][2])]))
    line3 = np.concatenate((center_gt[:,np.newaxis],line3_end[:,np.newaxis]),axis=1)
    
    plt.plot(line1[0,:],line1[1,:],'-b')
    plt.plot(line2[0,:],line2[1,:],'-b')
    plt.plot(line3[0,:],line3[1,:],'-b')
    
    
    center_output = outputs[ii,6:].detach().cpu()*32+32
    
    plt.plot(center_output[0],center_output[1],'ro',markersize=10)

    line1_end = (center_output + 10*np.array([outputs[ii][0],outputs[ii][3]]))
    line1 = np.concatenate((center_output[:,np.newaxis],line1_end[:,np.newaxis]),axis=1)
    
    line2_end = (center_output + 10*np.array([outputs[ii][1],outputs[ii][4]]))
    line2 = np.concatenate((center_output[:,np.newaxis],line2_end[:,np.newaxis]),axis=1)
    
    line3_end = (center_output + 10*np.array([outputs[ii][2],outputs[ii][5]]))
    line3 = np.concatenate((center_output[:,np.newaxis],line3_end[:,np.newaxis]),axis=1)
    
    plt.plot(line1[0,:],line1[1,:],'-r')
    plt.plot(line2[0,:],line2[1,:],'-r')
    plt.plot(line3[0,:],line3[1,:],'-r')

# %%
# Reduce the conv layers now

class junctionNet(nn.Module):

    def __init__(self):
        super().__init__()
                
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.maxpool = nn.MaxPool2d(2)

        self.fc0 = nn.Linear(2048, 4096)   
        self.fc1 = nn.Linear(4096, 4096)   
        self.fc2 = nn.Linear(4096, 512)   
        self.out = nn.Linear(512, 8)   
    
    def forward(self, x):
        
        x = self.conv1(x)
        x = F.relu(self.maxpool(x))
        x = self.conv2(x)
        x = F.relu(self.maxpool(x))
        x = self.conv3(x)
        x = F.relu(self.maxpool(x))
        x = self.conv4(x)
        x = F.relu(self.maxpool(x))
        x = x.view(-1,2048)

        x = F.relu(self.fc0(x))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)
        
        x_temp = x[:,:6].reshape(-1,2,3)
        x_temp = (x_temp/(torch.norm(x_temp,p=2,dim=1)).unsqueeze(1).repeat(1,2,1)).flatten(1)
        
        x = torch.cat((x_temp,x[:,6:]),axis=1)
        
        return x
        
model = junctionNet()
model = model.to(dev)
summary(model, input_size=[(1, 64, 64)])

optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)

n_epochs = 150

l1_loss = nn.L1Loss()
mse_loss = nn.MSELoss()

model.train();

for epoch in range(0,n_epochs):  # loop over the dataset multiple times

    if epoch == 0:
        train_loss_over_time = [] # to track the loss as the network trains
        test_loss_over_time = []
        
#     if epoch > 70:
#         optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)
        
    running_loss = 0
    num_batches = 0
    
    for batch_i, data in enumerate(train_loader):
        # get the input images and their corresponding labels
        num_batches += 1

        inputs, params, _, wedge = data
        
        inputs, wedge, params = inputs.to(dev), wedge.to(dev), params.to(dev)
        
        angle_params = torch.cat((torch.cos(params[:,:3]),torch.sin(params[:,:3])),axis=1)
        
        # zero the parameter (weight) gradients
        optimizer.zero_grad()
           
        # forward pass to get outputs
        output = model(inputs)
        
        # calculate the loss
        loss = mse_loss(output[:,6:],params[:,3:]) + .1*l1_loss(output[:,:6],angle_params) 
              
        # backward pass to calculate the parameter gradients
        loss.backward()

        # update the parameters
        optimizer.step()

        # to convert loss into a scalar and add it to running_loss, we use .item()
        running_loss += loss.item()

    # Calculate test data loss after each epoch
    with torch.no_grad():
        test_loss = 0
        num_batches_test = 0
        for batch_i, data in enumerate(test_loader):
            num_batches_test += 1
            
            inputs_test, params_test, _, wedges_test = data
            inputs_test, wedges_test, params_test = inputs_test.to(dev), wedges_test.to(dev), params_test.to(dev)
            
            angle_params_test = torch.cat((torch.cos(params_test[:,:3]),torch.sin(params_test[:,:3])),axis=1)
            output_test = model(inputs_test)
            
            test_loss += mse_loss(output_test[:,6:],params_test[:,3:]) + .1*l1_loss(output_test[:,:6],angle_params_test) 


                    
        test_loss_over_time.append(test_loss/num_batches_test)

    # Calculate model loss:
    avg_loss = running_loss/num_batches
    train_loss_over_time.append(avg_loss)
    
  
    print('Epoch: {}, Avg. Train Loss: {}, Avg. Test Loss: {}'.format(epoch + 1, train_loss_over_time[-1], test_loss_over_time[-1]))
    

print('Finished Training')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 64, 64]             320
#          MaxPool2d-2           [-1, 32, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          18,496
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5          [-1, 128, 16, 16]          73,856
#          MaxPool2d-6            [-1, 128, 8, 8]               0
#             Conv2d-7            [-1, 128, 8, 8]         147,584
#          MaxPool2d-8            [-1, 128, 4, 4]               0
#             Linear-9                 [-1, 4096]       8,392,704
#            Linear-10                 [-1, 4096]      16,781,312
#            Linear-11                  [-1, 512]       2,097,664
#            Linear-12                    [-1, 8]           4,104
# ================================================================
# Total params: 27,516,040
# Trainable params: 27,516,040
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB):
    plt.imshow(inputs[ii].cpu().squeeze(),cmap='gray')

    center_gt = gt[ii][3:]*32 + 32

    plt.plot(center_gt[0],center_gt[1],'bo',markersize=10)
    
    line1_end = (center_gt + 10*np.array([np.cos(gt[ii][0]),np.sin(gt[ii][0])]))
    line1 = np.concatenate((center_gt[:,np.newaxis],line1_end[:,np.newaxis]),axis=1)
    
    line2_end = (center_gt + 10*np.array([np.cos(gt[ii][1]),np.sin(gt[ii][1])]))
    line2 = np.concatenate((center_gt[:,np.newaxis],line2_end[:,np.newaxis]),axis=1)
    
    line3_end = (center_gt + 10*np.array([np.cos(gt[ii][2]),np.sin(gt[ii][2])]))
    line3 = np.concatenate((center_gt[:,np.newaxis],line3_end[:,np.newaxis]),axis=1)
    
    plt.plot(line1[0,:],line1[1,:],'-b')
    plt.plot(line2[0,:],line2[1,:],'-b')
    plt.plot(line3[0,:],line3[1,:],'-b')
    
    
    center_output = outputs[ii,6:].detach().cpu()*32+32
    
    plt.plot(center_output[0],center_output[1],'ro',markersize=10)

    line1_end = (center_output + 10*np.array([outputs[ii][0],outputs[ii][3]]))
    line1 = np.concatenate((center_output[:,np.newaxis],line1_end[:,np.newaxis]),axis=1)
    
    line2_end = (center_output + 10*np.array([outputs[ii][1],outputs[ii][4]]))
    line2 = np.concatenate((center_output[:,np.newaxis],line2_end[:,np.newaxis]),axis=1)
    
    line3_end = (center_output + 10*np.array([outputs[ii][2],outputs[ii][5]]))
    line3 = np.concatenate((center_output[:,np.newaxis],line3_end[:,np.newaxis]),axis=1)
    
    plt.plot(line1[0,:],line1[1,:],'-r')
    plt.plot(line2[0,:],line2[1,:],'-r')
    plt.plot(line3[0,:],line3[1,:],'-r')

# %% [markdown]
# # Question: Can we train all parameters with weighted mse?
# # Does evaluating the angles with a l1 loss provide any benefit?

# %%
# Reduce the conv layers now

class junctionNet(nn.Module):

    def __init__(self):
        super().__init__()
                
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.maxpool = nn.MaxPool2d(2)

        self.fc0 = nn.Linear(2048, 4096)   
        self.fc1 = nn.Linear(4096, 4096)   
        self.fc2 = nn.Linear(4096, 512)   
        self.out = nn.Linear(512, 8)   
    
    def forward(self, x):
        
        x = self.conv1(x)
        x = F.relu(self.maxpool(x))
        x = self.conv2(x)
        x = F.relu(self.maxpool(x))
        x = self.conv3(x)
        x = F.relu(self.maxpool(x))
        x = self.conv4(x)
        x = F.relu(self.maxpool(x))
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = x.view(-1,2048)

        x = F.relu(self.fc0(x))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)
        
        x_temp = x[:,:6].reshape(-1,2,3)
        x_temp = (x_temp/(torch.norm(x_temp,p=2,dim=1)).unsqueeze(1).repeat(1,2,1)).flatten(1)
        
        x = torch.cat((x_temp,x[:,6:]),axis=1)
        
        return x
        
model = junctionNet()
model = model.to(dev)
summary(model, input_size=[(1, 64, 64)])

optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)

n_epochs = 150

l1_loss = nn.L1Loss()
mse_loss = nn.MSELoss()

model.train();

for epoch in range(0,n_epochs):  # loop over the dataset multiple times

    if epoch == 0:
        train_loss_over_time = [] # to track the loss as the network trains
        test_loss_over_time = []
        
#     if epoch > 70:
#         optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)
        
    running_loss = 0
    num_batches = 0
    
    for batch_i, data in enumerate(train_loader):
        # get the input images and their corresponding labels
        num_batches += 1

        inputs, params, _, wedge = data
        
        inputs, wedge, params = inputs.to(dev), wedge.to(dev), params.to(dev)
        
        angle_params = torch.cat((torch.cos(params[:,:3]),torch.sin(params[:,:3])),axis=1)
        
        # zero the parameter (weight) gradients
        optimizer.zero_grad()
           
        # forward pass to get outputs
        output = model(inputs)
        
        # calculate the loss
        loss = mse_loss(output[:,6:],params[:,3:]) + .1*mse_loss(output[:,:6],angle_params) 
              
        # backward pass to calculate the parameter gradients
        loss.backward()

        # update the parameters
        optimizer.step()

        # to convert loss into a scalar and add it to running_loss, we use .item()
        running_loss += loss.item()

    # Calculate test data loss after each epoch
    with torch.no_grad():
        test_loss = 0
        num_batches_test = 0
        for batch_i, data in enumerate(test_loader):
            num_batches_test += 1
            
            inputs_test, params_test, _, wedges_test = data
            inputs_test, wedges_test, params_test = inputs_test.to(dev), wedges_test.to(dev), params_test.to(dev)
            
            angle_params_test = torch.cat((torch.cos(params_test[:,:3]),torch.sin(params_test[:,:3])),axis=1)
            output_test = model(inputs_test)
            
            test_loss += mse_loss(output_test[:,6:],params_test[:,3:]) + .1*mse_loss(output_test[:,:6],angle_params_test) 


                    
        test_loss_over_time.append(test_loss/num_batches_test)

    # Calculate model loss:
    avg_loss = running_loss/num_batches
    train_loss_over_time.append(avg_loss)
    
  
    print('Epoch: {}, Avg. Train Loss: {}, Avg. Test Loss: {}'.format(epoch + 1, train_loss_over_time[-1], test_loss_over_time[-1]))
    

print('Finished Training')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 64, 64]             320
#          MaxPool2d-2           [-1, 32, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          18,496
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-
# Epoch: 147, Avg. Train Loss: 8.683491944205289e-05, Avg. Test Loss: 0.0003027112106792629
# Epoch: 148, Avg. Train Loss: 6.784480959622134e-05, Avg. Test Loss: 0.000297515100101009
# Epoch: 149, Avg. Train Loss: 5.796015813008553e-05, Avg. Test Loss: 0.00030464891460724175
# Epoch: 150, Avg. Train Loss: 0.00010430207600139136, Avg. Test Loss: 0.0003322359989397228
# Finished Training

# %%
# What do the outputs look like? 

model.eval();

for batch_i, data in enumerate(test_loader):
    # get the input images and their corresponding labels
    inputs, params, _, _ = data
    
    inputs, params = inputs.to(dev), labels.to(dev)
        
    # forward pass to get outputs
    outputs = model(inputs).squeeze().detach().cpu()
    
    gt = params.cpu().squeeze()
    angle_params = torch.cat((torch.cos(params[:,:3]),torch.sin(params[:,:3])),axis=1).detach().cpu()
    params = params.cpu()

    
for ii in range(20):
    
    plt.figure()
    plt.imshow(inputs[ii].cpu().squeeze(),cmap='gray')

    center_gt = gt[ii][3:]*32 + 32

    plt.plot(center_gt[0],center_gt[1],'bo',markersize=10)
    
    line1_end = (center_gt + 10*np.array([np.cos(gt[ii][0]),np.sin(gt[ii][0])]))
    line1 = np.concatenate((center_gt[:,np.newaxis],line1_end[:,np.newaxis]),axis=1)
    
    line2_end = (center_gt + 10*np.array([np.cos(gt[ii][1]),np.sin(gt[ii][1])]))
    line2 = np.concatenate((center_gt[:,np.newaxis],line2_end[:,np.newaxis]),axis=1)
    
    line3_end = (center_gt + 10*np.array([np.cos(gt[ii][2]),np.sin(gt[ii][2])]))
    line3 = np.concatenate((center_gt[:,np.newaxis],line3_end[:,np.newaxis]),axis=1)
    
    plt.plot(line1[0,:],line1[1,:],'-b')
    plt.plot(line2[0,:],line2[1,:],'-b')
    plt.plot(line3[0,:],line3[1,:],'-b')
    
    
    center_output = outputs[ii,6:].detach().cpu()*32+32
    
    plt.plot(center_output[0],center_output[1],'ro',markersize=10)

    line1_end = (center_output + 10*np.array([outputs[ii][0],outputs[ii][3]]))
    line1 = np.concatenate((center_output[:,np.newaxis],line1_end[:,np.newaxis]),axis=1)
    
    line2_end = (center_output + 10*np.array([outputs[ii][1],outputs[ii][4]]))
    line2 = np.concatenate((center_output[:,np.newaxis],line2_end[:,np.newaxis]),axis=1)
    
    line3_end = (center_output + 10*np.array([outputs[ii][2],outputs[ii][5]]))
    line3 = np.concatenate((center_output[:,np.newaxis],line3_end[:,np.newaxis]),axis=1)
    
    plt.plot(line1[0,:],line1[1,:],'-r')
    plt.plot(line2[0,:],line2[1,:],'-r')
    plt.plot(line3[0,:],line3[1,:],'-r')
    
    # How do the two losses compare?
    
    loss1 = mse_loss(outputs[:,6:],params[:,3:]).item() + .1*l1_loss(outputs[:,:6],angle_params).item()
    new_loss = mse_loss(outputs[:,6:],params[:,3:]).item() + .1*mse_loss(outputs[:,:6],angle_params).item()
    
    print(loss1,new_loss)

    # New loss is lower: just use MSE
# Out:
# 0.001426418601477053 0.0001329135979176499
# 0.001426418601477053 0.0001329135979176499
# 0.001426418601477053 0.0001329135979176499
# 0.001426418601477053 0.0001329135979176499
# 0.001426418601477053 0.0001329135979176499
# 0.001426418601477053 0.0001329135979176499
# 0.001426418601477053 0.0001329135979176499
# 0.001426418601477053 0.0001329135979176499
# 0.001426418601477053 0.0001329135979176499
# 0.001426418601477053 0.0001329135979176499
# 0.001426418601477053 0.0001329135979176499
# 0.001426418601477053 0.0001329135979176499
# 0.001426418601477053 0.0001329135979176499
# 0.001426418601477053 0.0001329135979176499
# 0.001426418601477053 0.0001329135979176499
# 0.001426418601477053 0.0001329135979176499
# 0.001426418601477053 0.0001329135979176499
# 0.001426418601477053 0.0001329135979176499
# 0.001426418601477053 0.0001329135979176499
# 0.001426418601477053 0.0001329135979176499

# %% [markdown]
# # How simple/small can we really go?

# %%
# Reduce the conv layers now

class junctionNet(nn.Module):

    def __init__(self):
        super().__init__()
                
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.maxpool = nn.MaxPool2d(2)

        self.fc0 = nn.Linear(2048, 4096)    
        self.fc2 = nn.Linear(4096, 512)   
        self.out = nn.Linear(512, 8)   
    
    def forward(self, x):
        
        x = self.conv1(x)
        x = F.relu(self.maxpool(x))
        x = self.conv2(x)
        x = F.relu(self.maxpool(x))
        x = self.conv3(x)
        x = F.relu(self.maxpool(x))
        x = self.conv4(x)
        x = F.relu(self.maxpool(x))
        x = x.view(-1,2048)

        x = F.relu(self.fc0(x))
#         x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)
        
        x_temp = x[:,:6].reshape(-1,2,3)
        x_temp = (x_temp/(torch.norm(x_temp,p=2,dim=1)).unsqueeze(1).repeat(1,2,1)).flatten(1)
        
        x = torch.cat((x_temp,x[:,6:]),axis=1)
        
        return x
        
model = junctionNet()
model = model.to(dev)
summary(model, input_size=[(1, 64, 64)])

optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)

n_epochs = 150

l1_loss = nn.L1Loss()
mse_loss = nn.MSELoss()

model.train();

for epoch in range(0,n_epochs):  # loop over the dataset multiple times

    if epoch == 0:
        train_loss_over_time = [] # to track the loss as the network trains
        test_loss_over_time = []
        
#     if epoch > 70:
#         optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)
        
    running_loss = 0
    num_batches = 0
    
    for batch_i, data in enumerate(train_loader):
        # get the input images and their corresponding labels
        num_batches += 1

        inputs, params, _, wedge = data
        
        inputs, wedge, params = inputs.to(dev), wedge.to(dev), params.to(dev)
        
        angle_params = torch.cat((torch.cos(params[:,:3]),torch.sin(params[:,:3])),axis=1)
        
        # zero the parameter (weight) gradients
        optimizer.zero_grad()
           
        # forward pass to get outputs
        output = model(inputs)
        
        # calculate the loss
        loss = mse_loss(output[:,6:],params[:,3:]) + .1*mse_loss(output[:,:6],angle_params) 
              
        # backward pass to calculate the parameter gradients
        loss.backward()

        # update the parameters
        optimizer.step()

        # to convert loss into a scalar and add it to running_loss, we use .item()
        running_loss += loss.item()

    # Calculate test data loss after each epoch
    with torch.no_grad():
        test_loss = 0
        num_batches_test = 0
        for batch_i, data in enumerate(test_loader):
            num_batches_test += 1
            
            inputs_test, params_test, _, wedges_test = data
            inputs_test, wedges_test, params_test = inputs_test.to(dev), wedges_test.to(dev), params_test.to(dev)
            
            angle_params_test = torch.cat((torch.cos(params_test[:,:3]),torch.sin(params_test[:,:3])),axis=1)
            output_test = model(inputs_test)
            
            test_loss += mse_loss(output_test[:,6:],params_test[:,3:]) + .1*mse_loss(output_test[:,:6],angle_params_test) 


                    
        test_loss_over_time.append(test_loss/num_batches_test)

    # Calculate model loss:
    avg_loss = running_loss/num_batches
    train_loss_over_time.append(avg_loss)
    
  
    print('Epoch: {}, Avg. Train Loss: {}, Avg. Test Loss: {}'.format(epoch + 1, train_loss_over_time[-1], test_loss_over_time[-1]))
    

print('Finished Training')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 64, 64]             320
#          MaxPool2d-2           [-1, 32, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          18,496
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5          [-1, 128, 16, 16]          73,856
#          MaxPool2d-6            [-1, 128, 8, 8]               0
#             Conv2d-7            [-1, 128, 8, 8]         147,584
#          MaxPool2d-8            [-1, 128, 4, 4]               0
#             Linear-9                 [-1, 4096]       8,392,704
#            Linear-10                  [-1, 512]       2,097,664
#            Linear-11                    [-1, 8]           4,104
# ================================================================
# Total params: 10,734,728
# Trainable params: 10,734,728
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 2.30
# Params size (MB): 40.95
# Estimated Total Size (MB): 43.27
# ----------------------------------------------------------------
# Epoch: 1, Avg. Train Loss: 0.0989027396282729, Avg. Test Loss: 0.04625764861702919
# Epoch: 2, Avg. Train Loss: 0.03301506397478721, Avg. Test Loss: 0.025245096534490585
# Epoch: 3, Avg. Train Loss: 0.01835404373705387, Avg. Test Loss: 0.01469517033547163
# Epoch: 4, Avg. Train Loss: 0.012250236010945895, Avg. Test Loss: 0.011858781799674034
# Epoch: 5, Avg. Train Loss: 0.008805333899662775, Avg. Test Loss: 0.007983669638633728
# Epoch: 6, Avg. Train Loss: 0.00689790170530186, Avg. Test Loss: 0.006608560215681791
# Epoch: 7, Avg. Train Loss: 0.005729865853893844, Avg. Test Loss: 0.005609361920505762
# Epoch: 8, Avg. Train Loss: 0.004649848519714878, Avg. Test Loss: 0.004905408713966608
# Epoch: 9, Avg. Train Loss: 0.0042230096618261406, Avg. Test Loss: 0.004385301377624273
# Epoch: 10, Avg. Train Loss: 0.0036842662430204014, Avg. Test Loss: 0.004455276764929295
# Epoch: 11, Avg. Train Loss: 0.0032288529026760337, Avg. Test Loss: 0.004002863075584173
# Epoch: 12, Avg. Train Loss: 0.002929679522811271, Avg. Test Loss: 0.003035763744264841
# Epoch: 13, Avg. Train Loss: 0.002701740581131376, Avg. Test Loss: 0.0029339976608753204
# Epoch: 14, Avg. Train Loss: 0.003166540031430914, Avg. Test Loss: 0.00300502753816545
# Epoch: 15, Avg. Train Loss: 0.002373548519715448, Avg. Test Loss: 0.002491795225068927
# Epoch: 16, Avg. Train Loss: 0.002174460776971982, Avg. Test Loss: 0.002373390132561326
# Epoch: 137, Avg. Train Loss: 6.525464043935405e-05, Avg. Test Loss: 0.0002935886150225997
# Epoch: 138, Avg. Train Loss: 7.229438006641645e-05, Avg. Test Loss: 0.0003010523214470595
# Epoch: 139, Avg. Train Loss: 7.16416445785024e-05, Avg. Test Loss: 0.00033656758023425937
# Epoch: 140, Avg. Train Loss: 7.775996910983368e-05, Avg. Test Loss: 0.0003222809755243361
# Epoch: 141, Avg. Train Loss: 6.371631010123939e-05, Avg. Test Loss: 0.00029768989770673215
# Epoch: 142, Avg. Train Loss: 8.132251613835037e-05, Avg. Test Loss: 0.0002890442556235939
# Epoch: 143, Avg. Train Loss: 7.703657157595872e-05, Avg. Test Loss: 0.0003043317119590938
# Epoch: 144, Avg. Train Loss: 7.844869355989538e-05, Avg. Test Loss: 0.00029086644644849
# Epoch: 145, Avg. Train Loss: 7.090202435553211e-05, Avg. Test Loss: 0.0003006046754308045
# Epoch: 146, Avg. Train Loss: 7.772441664094324e-05, Avg. Test Loss: 0.0002903091663029045
# Epoch: 147, Avg. Train Loss: 6.904860456415917e-05, Avg. Test Loss: 0.0003163687069900334
# Epoch: 148, Avg. Train Loss: 7.515659417549614e-05, Avg. Test Loss: 0.0002958850236609578
# Epoch: 149, Avg. Train Loss: 6.487032833854969e-05, Avg. Test Loss: 0.00027684972155839205
# Epoch: 150, Avg. Train Loss: 5.379156288707985e-05, Avg. Test Loss: 0.0002863783447537571
# Finished Training

# %%
# What do the outputs look like? 

model.eval();

for batch_i, data in enumerate(test_loader):
    # get the input images and their corresponding labels
    inputs, params, _, _ = data
    
    inputs, params = inputs.to(dev), labels.to(dev)
        
    # forward pass to get outputs
    outputs = model(inputs).squeeze().detach().cpu()
    
    gt = params.cpu().squeeze()
    angle_params = torch.cat((torch.cos(params[:,:3]),torch.sin(params[:,:3])),axis=1).detach().cpu()
    params = params.cpu()

    
for ii in range(20):
    
    plt.figure()
    plt.imshow(inputs[ii].cpu().squeeze(),cmap='gray')

    center_gt = gt[ii][3:]*32 + 32

    plt.plot(center_gt[0],center_gt[1],'bo',markersize=10)
    
    line1_end = (center_gt + 10*np.array([np.cos(gt[ii][0]),np.sin(gt[ii][0])]))
    line1 = np.concatenate((center_gt[:,np.newaxis],line1_end[:,np.newaxis]),axis=1)
    
    line2_end = (center_gt + 10*np.array([np.cos(gt[ii][1]),np.sin(gt[ii][1])]))
    line2 = np.concatenate((center_gt[:,np.newaxis],line2_end[:,np.newaxis]),axis=1)
    
    line3_end = (center_gt + 10*np.array([np.cos(gt[ii][2]),np.sin(gt[ii][2])]))
    line3 = np.concatenate((center_gt[:,np.newaxis],line3_end[:,np.newaxis]),axis=1)
    
    plt.plot(line1[0,:],line1[1,:],'-b')
    plt.plot(line2[0,:],line2[1,:],'-b')
    plt.plot(line3[0,:],line3[1,:],'-b')
    
    
    center_output = outputs[ii,6:].detach().cpu()*32+32
    
    plt.plot(center_output[0],center_output[1],'ro',markersize=10)

    line1_end = (center_output + 10*np.array([outputs[ii][0],outputs[ii][3]]))
    line1 = np.concatenate((center_output[:,np.newaxis],line1_end[:,np.newaxis]),axis=1)
    
    line2_end = (center_output + 10*np.array([outputs[ii][1],outputs[ii][4]]))
    line2 = np.concatenate((center_output[:,np.newaxis],line2_end[:,np.newaxis]),axis=1)
    
    line3_end = (center_output + 10*np.array([outputs[ii][2],outputs[ii][5]]))
    line3 = np.concatenate((center_output[:,np.newaxis],line3_end[:,np.newaxis]),axis=1)
    
    plt.plot(line1[0,:],line1[1,:],'-r')
    plt.plot(line2[0,:],line2[1,:],'-r')
    plt.plot(line3[0,:],line3[1,:],'-r')
    
    # How do the two losses compare?
    
loss1 = mse_loss(outputs[:,6:],params[:,3:]).item() + .1*l1_loss(outputs[:,:6],angle_params).item()
new_loss = mse_loss(outputs[:,6:],params[:,3:]).item() + .1*mse_loss(outputs[:,:6],angle_params).item()

print(loss1,new_loss)

    # New loss is lower: just use MSE
# Out:
# 0.0013095388494548388 0.00011861026723636314

# %%
# Reduce the fc layers

class junctionNet(nn.Module):

    def __init__(self):
        super().__init__()
                
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.maxpool = nn.MaxPool2d(2)

        self.fc0 = nn.Linear(2048, 4096)    
        self.out = nn.Linear(4096, 8)   
    
    def forward(self, x):
        
        x = self.conv1(x)
        x = F.relu(self.maxpool(x))
        x = self.conv2(x)
        x = F.relu(self.maxpool(x))
        x = self.conv3(x)
        x = F.relu(self.maxpool(x))
        x = self.conv4(x)
        x = F.relu(self.maxpool(x))
        x = x.view(-1,2048)

        x = F.relu(self.fc0(x))
#         x = F.relu(self.fc1(x))
#         x = F.relu(self.fc2(x))
        x = self.out(x)
        
        x_temp = x[:,:6].reshape(-1,2,3)
        x_temp = (x_temp/(torch.norm(x_temp,p=2,dim=1)).unsqueeze(1).repeat(1,2,1)).flatten(1)
        
        x = torch.cat((x_temp,x[:,6:]),axis=1)
        
        return x
        
model = junctionNet()
model = model.to(dev)
summary(model, input_size=[(1, 64, 64)])

optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)

n_epochs = 150

l1_loss = nn.L1Loss()
mse_loss = nn.MSELoss()

model.train();

for epoch in range(0,n_epochs):  # loop over the dataset multiple times

    if epoch == 0:
        train_loss_over_time = [] # to track the loss as the network trains
        test_loss_over_time = []
        
#     if epoch > 70:
#         optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)
        
    running_loss = 0
    num_batches = 0
    
    for batch_i, data in enumerate(train_loader):
        # get the input images and their corresponding labels
        num_batches += 1

        inputs, params, _, wedge = data
        
        inputs, wedge, params = inputs.to(dev), wedge.to(dev), params.to(dev)
        
        angle_params = torch.cat((torch.cos(params[:,:3]),torch.sin(params[:,:3])),axis=1)
        
        # zero the parameter (weight) gradients
        optimizer.zero_grad()
           
        # forward pass to get outputs
        output = model(inputs)
        
        # calculate the loss
        loss = mse_loss(output[:,6:],params[:,3:]) + .1*mse_loss(output[:,:6],angle_params) 
              
        # backward pass to calculate the parameter gradients
        loss.backward()

        # update the parameters
        optimizer.step()

        # to convert loss into a scalar and add it to running_loss, we use .item()
        running_loss += loss.item()

    # Calculate test data loss after each epoch
    with torch.no_grad():
        test_loss = 0
        num_batches_test = 0
        for batch_i, data in enumerate(test_loader):
            num_batches_test += 1
            
            inputs_test, params_test, _, wedges_test = data
            inputs_test, wedges_test, params_test = inputs_test.to(dev), wedges_test.to(dev), params_test.to(dev)
            
            angle_params_test = torch.cat((torch.cos(params_test[:,:3]),torch.sin(params_test[:,:3])),axis=1)
            output_test = model(inputs_test)
            
            test_loss += mse_loss(output_test[:,6:],params_test[:,3:]) + .1*mse_loss(output_test[:,:6],angle_params_test) 


                    
        test_loss_over_time.append(test_loss/num_batches_test)

    # Calculate model loss:
    avg_loss = running_loss/num_batches
    train_loss_over_time.append(avg_loss)
    
  
    print('Epoch: {}, Avg. Train Loss: {}, Avg. Test Loss: {}'.format(epoch + 1, train_loss_over_time[-1], test_loss_over_time[-1]))
    

print('Finished Training')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 64, 64]             320
#          MaxPool2d-2           [-1, 32, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          18,496
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5          [-1, 128, 16, 16]          73,856
#          MaxPool2d-6            [-1, 128, 8, 8]               0
#             Conv2d-7            [-1, 128, 8, 8]         147,584
#          MaxPool2d-8            [-1, 128, 4, 4]               0
#             Linear-9                 [-1, 4096]       8,392,704
#            Linear-10                    [-1, 8]          32,776
# ================================================================
# Total params: 8,665,736
# Trainable params: 8,665,736
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 2.30
# Params size (MB): 33.06
# Estimated Total Size (MB): 35.37
# ----------------------------------------------------------------
# Epoch: 1, Avg. Train Loss: 0.08616159501321176, Avg. Test Loss: 0.039241205900907516
# Epoch: 2, Avg. Train Loss: 0.028744954867836306, Avg. Test Loss: 0.021247342228889465
# Epoch: 3, Avg. Train Loss: 0.016603618542499404, Avg. Test Loss: 0.014325845055282116
# Epoch: 4, Avg. Train Loss: 0.011064032958272626, Avg. Test Loss: 0.009905469603836536
# Epoch: 5, Avg. Train Loss: 0.008191789933206404, Avg. Test Loss: 0.007470899727195501
# Epoch: 6, Avg. Train Loss: 0.006636710152687395, Avg. Test Loss: 0.006068876013159752
# Epoch: 7, Avg. Train Loss: 0.005492040354703717, Avg. Test Loss: 0.005444769281893969
# Epoch: 128, Avg. Train Loss: 0.00010474628772285273, Avg. Test Loss: 0.0004630088806152344
# Epoch: 129, Avg. Train Loss: 9.268307493424371e-05, Avg. Test Loss: 0.0004786034987773746
# Epoch: 130, Avg. Train Loss: 9.640828419137774e-05, Avg. Test Loss: 0.0004872992867603898
# Epoch: 131, Avg. Train Loss: 0.00010261345416759415, Avg. Test Loss: 0.00047857966274023056
# Epoch: 132, Avg. Train Loss: 9.629926928883993e-05, Avg. Test Loss: 0.0005023651756346226
# Epoch: 133, Avg. Train Loss: 9.866171150112196e-05, Avg. Test Loss: 0.00047905233805067837
# Epoch: 134, Avg. Train Loss: 0.0001055182570245747, Avg. Test Loss: 0.0004711410729214549
# Epoch: 135, Avg. Train Loss: 9.042905914932763e-05, Avg. Test Loss: 0.0004668311739806086
# Epoch: 136, Avg. Train Loss: 7.93940900835236e-05, Avg. Test Loss: 0.0004932985757477582
# Epoch: 137, Avg. Train Loss: 8.604350022163571e-05, Avg. Test Loss: 0.00046353827929124236
# Epoch: 138, Avg. Train Loss: 9.019388626791838e-05, Avg. Test Loss: 0.00044214888475835323
# Epoch: 139, Avg. Train Loss: 8.746824149805915e-05, Avg. Test Loss: 0.0004542514798231423
# Epoch: 140, Avg. Train Loss: 8.796096179353566e-05, Avg. Test Loss: 0.0004608377639669925
# Epoch: 141, Avg. Train Loss: 7.879065477241323e-05, Avg. Test Loss: 0.0004496983310673386
# Epoch: 142, Avg. Train Loss: 7.563577209486325e-05, Avg. Test Loss: 0.00044359517050907016
# Epoch: 143, Avg. Train Loss: 8.64448538135655e-05, Avg. Test Loss: 0.0004394363204482943
# Epoch: 144, Avg. Train Loss: 9.22239833016647e-05, Avg. Test Loss: 0.0004513254971243441
# Epoch: 145, Avg. Train Loss: 8.351072963919518e-05, Avg. Test Loss: 0.0004487564438022673
# Epoch: 146, Avg. Train Loss: 7.250818399530973e-05, Avg. Test Loss: 0.0004562832764349878
# Epoch: 147, Avg. Train Loss: 8.274853256914546e-05, Avg. Test Loss: 0.0004632790223695338
# Epoch: 148, Avg. Train Loss: 7.488283040669665e-05, Avg. Test Loss: 0.0004457336908672005
# Epoch: 149, Avg. Train Loss: 7.377185269005541e-05, Avg. Test Loss: 0.00044348646770231426
# Epoch: 150, Avg. Train Loss: 6.844235067546834e-05, Avg. Test Loss: 0.00044929530122317374
# Finished Training

# %% [markdown]
# ### Perforance degrades around ~8 mil parameters

# %% [markdown]
# # Part 4: The Overlap Loss

# %% [markdown]
# Overlap loss is the amount of overlap wedges contain.

# %% [markdown]
# ### Question: Can we train this network with the overlap loss if we encode angles as sin and cosine?

# %%
# Reduce the conv layers now

class junctionNet(nn.Module):

    def __init__(self):
        super().__init__()
                
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.conv6 = nn.Conv2d(128, 128, kernel_size=3, padding=1)
        self.maxpool = nn.MaxPool2d(2)

        self.fc0 = nn.Linear(2048, 4096)   
        self.fc1 = nn.Linear(4096, 4096)   
        self.fc2 = nn.Linear(4096, 512)   
        self.out = nn.Linear(512, 8)   
    
    def forward(self, x):
        
        x = self.conv1(x)
        x = F.relu(self.maxpool(x))
        x = self.conv2(x)
        x = F.relu(self.maxpool(x))
        x = self.conv3(x)
        x = F.relu(self.maxpool(x))
        x = self.conv4(x)
        x = F.relu(self.maxpool(x))
        x = F.relu(self.conv5(x))
        x = F.relu(self.conv6(x))
        x = x.view(-1,2048)

        x = F.relu(self.fc0(x))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.out(x)
        
        x_temp = x[:,:6].reshape(-1,2,3)
        x_temp = (x_temp/(torch.norm(x_temp,p=2,dim=1)).unsqueeze(1).repeat(1,2,1)).flatten(1)
        
        x = torch.cat((x_temp,x[:,6:]),axis=1)
        
        return x
        
model = junctionNet()
model = model.to(dev)
summary(model, input_size=[(1, 64, 64)])
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 32, 64, 64]             320
#          MaxPool2d-2           [-1, 32, 32, 32]               0
#             Conv2d-3           [-1, 64, 32, 32]          18,496
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5          [-1, 128, 16, 16]          73,856
#          MaxPool2d-6            [-1, 128, 8, 8]               0
#             Conv2d-7            [-1, 128, 8, 8]         147,584
#          MaxPool2d-8            [-1, 128, 4, 4]               0
#             Conv2d-9            [-1, 128, 4, 4]         147,584
#            Conv2d-10            [-1, 128, 4, 4]         147,584
#            Linear-11                 [-1, 4096]       8,392,704
#            Linear-12                 [-1, 4096]      16,781,312
#            Linear-13                  [-1, 512]       2,097,664
#            Linear-14                    [-1, 8]           4,104
# ================================================================
# Total params: 27,811,208
# Trainable params: 27,811,208
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 2.36
# Params size (MB): 106.09
# Estimated Total Size (MB): 108.47
# ----------------------------------------------------------------

# %%
def overlap_loss(output, target, R=50):

    pred_wedges = dists2indicators(params2dists(output.unsqueeze(-1).unsqueeze(-1),R)).squeeze()
    
    loss1 = torch.sum(pred_wedges + target - 2*pred_wedges*target,axis=(1,2,3))/torch.numel(pred_wedges)
    loss2 = torch.sum(pred_wedges[:,[2,0,1],:,:] + target - 2*pred_wedges[:,[2,0,1],:,:]*target,axis=(1,2,3))/torch.numel(pred_wedges)
    loss3 = torch.sum(pred_wedges[:,[1,2,0],:,:] + target - 2*pred_wedges[:,[1,2,0],:,:]*target,axis=(1,2,3))/torch.numel(pred_wedges)

    min_loss,_ = torch.Tensor.min(torch.stack((loss1,loss2,loss3),axis=1),axis=1)
    
    return min_loss

# %% [markdown]
# # 2/6/23 Mia Comment: The loss almost certainly doesn't work and favors incorrectly labeling wedges to minimize overlap.

# %%
model = junctionNet()
model = model.to(dev)

optimizer = torch.optim.Adam(model.parameters(), lr=0.00001)

n_epochs = 150

mse_loss = nn.MSELoss()

model.train();

for epoch in range(0,n_epochs):  # loop over the dataset multiple times

    if epoch == 0:
        train_loss_over_time = [] # to track the loss as the network trains
        test_loss_over_time = []
        
#     if epoch > 70:
#         optimizer = torch.optim.Adam(model.parameters(), lr=0.00005)
        
    running_loss = 0
    num_batches = 0
    
    for batch_i, data in enumerate(train_loader):
        # get the input images and their corresponding labels
        num_batches += 1

        inputs, params, _, wedges = data
        
        inputs, wedges, params = inputs.to(dev), wedges.to(dev), params.to(dev)
                
        # zero the parameter (weight) gradients
        optimizer.zero_grad()
           
        # forward pass to get outputs
        output_temp = model(inputs)
        
        output = torch.cat((torch.atan2(output_temp[:,3:6],output_temp[:,:3]),output_temp[:,6:]),axis=1)
        
        # calculate the loss
        loss = overlap_loss(output,wedges).mean()
           
        # backward pass to calculate the parameter gradients
        loss.backward()

        # update the parameters
        optimizer.step()

        # to convert loss into a scalar and add it to running_loss, we use .item()
        running_loss += loss.item()

    # Calculate test data loss after each epoch
    with torch.no_grad():
        test_loss = 0
        num_batches_test = 0
        for batch_i, data in enumerate(test_loader):
            num_batches_test += 1
            
            inputs_test, params_test, _, wedges_test = data
            inputs_test, wedges_test, params_test = inputs_test.to(dev), wedges_test.to(dev), params_test.to(dev)
            output_test_temp = model(inputs_test)
            
            output_test = torch.cat((torch.atan2(output_test_temp[:,3:6],output_test_temp[:,:3]),output_test_temp[:,6:]),axis=1)

            test_loss += overlap_loss(output_test,wedges_test).mean()

                    
        test_loss_over_time.append(test_loss/num_batches_test)

    # Calculate model loss:
    avg_loss = running_loss/num_batches
    train_loss_over_time.append(avg_loss)
    
  
    print('Epoch: {}, Avg. Train Loss: {}, Avg. Test Loss: {}'.format(epoch + 1, train_loss_over_time[-1], test_loss_over_time[-1]))
    

print('Finished Training')
# Out:
# Epoch: 1, Avg. Train Loss: 0.0024585618096513344, Avg. Test Loss: 0.0017867685528472066
# Epoch: 2, Avg. Train Loss: 0.0015859037014546201, Avg. Test Loss: 0.0014369012787938118
# Epoch: 3, Avg. Train Loss: 0.0014323557391488816, Avg. Test Loss: 0.0013787790667265654
# Epoch: 4, Avg. Train Loss: 0.0013282226768377072, Avg. Test Loss: 0.001292213797569275
# Epoch: 5, Avg. Train Loss: 0.0012483291910029947, Avg. Test Loss: 0.001216107397340238
# Epoch: 6, Avg. Train Loss: 0.0012503443285822868, Avg. Test Loss: 0.0012603291543200612
# Epoch: 7, Avg. Train Loss: 0.0011693086903131402, Avg. Test Loss: 0.0012138125021010637
# Epoch: 8, Avg. Train Loss: 0.001171627120621612, Avg. Test Loss: 0.0011313683353364468
# Epoch: 9, Avg. Train Loss: 0.0011354103828232517, Avg. Test Loss: 0.0010827135993167758
# Epoch: 10, Avg. Train Loss: 0.0011402813933433637, Avg. Test Loss: 0.0011084674624726176
# Epoch: 11, Avg. Train Loss: 0.0010875710659413872, Avg. Test Loss: 0.0010041026398539543
# Epoch: 12, Avg. Train Loss: 0.000946050277322202, Avg. Test Loss: 0.0008824052638374269
# Epoch: 13, Avg. Train Loss: 0.0008623184858793941, Avg. Test Loss: 0.0008431897149421275
# Epoch: 14, Avg. Train Loss: 0.0008516272892901565, Avg. Test Loss: 0.0007891888963058591
# Epoch: 15, Avg. Train Loss: 0.0007944385812152177, Avg. Test Loss: 0.000827691110316664
# Epoch: 16, Avg. Train Loss: 0.0008026088108582532, Avg. Test Loss: 0.0008010959136299789
# Epoch: 17, Avg. Train Loss: 0.0007263118945582606, Avg. Test Loss: 0.000724464247468859
# Epoch: 18, Avg. Train Loss: 0.0007076297643567052, Avg. Test Loss: 0.0006535323918797076
# Epoch: 19, Avg. Train Loss: 0.0006466672882465097, Avg. Test Loss: 0.0006503781769424677
# Epoch: 20, Avg. Train Loss: 0.0006699783484424081, Avg. Test Loss: 0.0006521342438645661
# Epoch: 21, Avg. Train Loss: 0.000611610767116551, Avg. Test Loss: 0.000570391770452261
# Epoch: 22, Avg. Train Loss: 0.0005935231665395857, Avg. Test Loss: 0.0006019818247295916
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-358-f398e65468f2> in <module>
#      59             inputs_test, params_test, _, wedges_test = data
#      60             inputs_test, wedges_test, params_test = inputs_test.to(dev), wedges_test.to(dev), params_test.to(dev)
# ---> 61             output_test_temp = model(inputs_test)
#      62
#      63             output_test = torch.cat((torch.atan2(output_test_temp[:,3:6],output_test_temp[:,:3]),output_test_temp[:,6:]),axis=1)
#
# ~/.conda/envs/torch_cuda9/lib/python3.6/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# <ipython-input-344-deca1d4a05a9> in forward(self, x)
#      36         x = F.relu(self.fc1(x))
#      37         x = F.relu(self.fc2(x))
# ---> 38         x = self.out(x)
#      39
#      40         x_temp = x[:,:6].reshape(-1,2,3)
#
# ~/.conda/envs/torch_cuda9/lib/python3.6/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1162             self._is_full_backward_hook = None
#    1163
# -> 1164     def __getattr__(self, name: str) -> Union[Tensor, 'Module']:
#    1165         if '_parameters' in self.__dict__:
#    1166             _parameters = self.__dict__['_parameters']
#
# KeyboardInterrupt:

# %%
plt.figure()
plt.plot(train_loss_over_time)
plt.plot(test_loss_over_time)
plt.legend(['Avg Train Loss','Avg Test Loss'])

# %%
# What do the outputs look like? 

model.eval();

for batch_i, data in enumerate(test_loader):
    # get the input images and their corresponding labels
    inputs, params, _, _ = data
    
    inputs, params = inputs.to(dev), labels.to(dev)
        
    # forward pass to get outputs
    outputs = model(inputs).squeeze().detach().cpu()
    
    gt = params.cpu().squeeze()
    angle_params = torch.cat((torch.cos(params[:,:3]),torch.sin(params[:,:3])),axis=1).detach().cpu()
    params = params.cpu()

    
for ii in range(20):
    
    plt.figure()
    plt.imshow(inputs[ii].cpu().squeeze(),cmap='gray')

    center_gt = gt[ii][3:]*32 + 32

    plt.plot(center_gt[0],center_gt[1],'bo',markersize=10)
    
    line1_end = (center_gt + 10*np.array([np.cos(gt[ii][0]),np.sin(gt[ii][0])]))
    line1 = np.concatenate((center_gt[:,np.newaxis],line1_end[:,np.newaxis]),axis=1)
    
    line2_end = (center_gt + 10*np.array([np.cos(gt[ii][1]),np.sin(gt[ii][1])]))
    line2 = np.concatenate((center_gt[:,np.newaxis],line2_end[:,np.newaxis]),axis=1)
    
    line3_end = (center_gt + 10*np.array([np.cos(gt[ii][2]),np.sin(gt[ii][2])]))
    line3 = np.concatenate((center_gt[:,np.newaxis],line3_end[:,np.newaxis]),axis=1)
    
    plt.plot(line1[0,:],line1[1,:],'-b')
    plt.plot(line2[0,:],line2[1,:],'-b')
    plt.plot(line3[0,:],line3[1,:],'-b')
    
    
    center_output = outputs[ii,6:].detach().cpu()*32+32
    
    plt.plot(center_output[0],center_output[1],'ro',markersize=10)

    line1_end = (center_output + 10*np.array([outputs[ii][0],outputs[ii][3]]))
    line1 = np.concatenate((center_output[:,np.newaxis],line1_end[:,np.newaxis]),axis=1)
    
    line2_end = (center_output + 10*np.array([outputs[ii][1],outputs[ii][4]]))
    line2 = np.concatenate((center_output[:,np.newaxis],line2_end[:,np.newaxis]),axis=1)
    
    line3_end = (center_output + 10*np.array([outputs[ii][2],outputs[ii][5]]))
    line3 = np.concatenate((center_output[:,np.newaxis],line3_end[:,np.newaxis]),axis=1)
    
    plt.plot(line1[0,:],line1[1,:],'-r')
    plt.plot(line2[0,:],line2[1,:],'-r')
    plt.plot(line3[0,:],line3[1,:],'-r')
    
    # Gets stuck?

# %%
# It's just not quite as good all else held equal!
